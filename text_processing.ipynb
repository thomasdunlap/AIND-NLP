# %% [markdown]
# # Text Processing
#
# ## Capturing Text Data
#
# ### Plain Text

# %%
import os

# Read in a plain text file
with open(os.path.join("data", "hieroglyph.txt"), "r") as f:
    text = f.read()
    print(text)
# Out:
# Hieroglyphic writing dates from c. 3000 BC, and is composed of hundreds of symbols. A hieroglyph can represent a word, a sound, or a silent determinative; and the same symbol can serve different purposes in different contexts. Hieroglyphs were a formal script, used on stone monuments and in tombs, that could be as detailed as individual works of art.

# %% [markdown]
# ### Tabular Data

# %%
import pandas as pd

# Extract text column from a dataframe
df = pd.read_csv(os.path.join("data", "news.csv"))
df.head()[['publisher', 'title']]

# Convert text column to lowercase
df['title'] = df['title'].str.lower()
df.head()[['publisher', 'title']]
# Out:
#       publisher                                              title
# 0      Livemint  fed's charles plosser sees high bar for change...
# 1  IFA Magazine  us open: stocks fall after fed official hints ...
# 2  IFA Magazine  fed risks falling 'behind the curve', charles ...
# 3     Moneynews  fed's plosser: nasty weather has curbed job gr...
# 4        NASDAQ  plosser: fed may have to accelerate tapering pace

# %% [markdown]
# ### Online Resource

# %%
import requests
import json

# Fetch data from a REST API
r = requests.get(
    "https://quotes.rest/qod.json")
res = r.json()
print(json.dumps(res, indent=4))

# Extract relevant object and field
q = res["contents"]["quotes"][0]
print(q["quote"], "\n--", q["author"])
# Out:
# {
#     "success": {
#         "total": 1
#     },
#     "contents": {
#         "quotes": [
#             {
#                 "quote": "Feeling grateful to or appreciative of someone or something in your life actually attracts more of the things that you appreciate and value into your life.",
#                 "length": "155",
#                 "author": "Christiane Northrup",
#                 "tags": [
#                     "grateful",
#                     "inspire",
#                     "tso-life"
#                 ],
#                 "category": "inspire",
#                 "date": "2018-11-10",
#                 "permalink": "https://theysaidso.com/quote/VDUQrzzY_1sBaTyLlZg6pQeF/christiane-northrup-feeling-grateful-to-or-appreciative-of-someone-or-something",
#                 "title": "Inspiring Quote of the day",
#                 "background": "https://theysaidso.com/img/bgs/man_on_the_mountain.jpg",
#                 "id": "VDUQrzzY_1sBaTyLlZg6pQeF"
#             }
#         ],
#         "copyright": "2017-19 theysaidso.com"
#     }
# }
# Feeling grateful to or appreciative of someone or something in your life actually attracts more of the things that you appreciate and value into your life.
# -- Christiane Northrup

# %% [markdown]
# ## Cleaning

# %%
import requests

# Fetch a web page
r = requests.get("https://www.udacity.com/courses/all")
print(r.text)
# Out:
# <!DOCTYPE html><html><head>
#   <meta charset="utf-8">
#   <script type="text/javascript" class="ng-star-inserted">window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(15),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,s){try{p?p-=1:o(s||new UncaughtException(t,n,e),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t,n){var e=n?null:c.now();i("err",[t,e])}var i=t("handle"),a=t(16),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),d=!0)}s.on("fn-start",function(t,n,e){d&&(p+=1)}),s.on("fn-err",function(t,n,e){d&&!e[l]&&(f(e,l,function(){return!0}),this.thrown=!0,o(e))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&&(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof b&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(18)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o=t(18)(r);n.exports=r ...
# ;NREUM.info={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",licenseKey:"2059d2614a",applicationID:"215318720",sa:1}</script><title></title>
#   <base href="/"><link rel="preload" href="runtime.ba5ea5387c29ed57e6f5.js" as="script"><link rel="preload" href="polyfills.ccfa850a0d710421501f.js" as="script"><link rel="preload" href="scripts.0ff312eb31880c12aac8.js" as="script"><link rel="preload" href="main.c07d084d0124c9c4276f.js" as="script">
#
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <link rel="icon" type="image/x-icon" href="favicon.ico">
#   <script type="text/javascript" class="ng-star-inserted">window.DISABLE_EARLY_ANALYTICS = false;if (typeof Object.assign == 'function') {window.ACTIVE_EXPERIMENTS = window.ACTIVE_EXPERIMENTS || {};Object.assign(window.ACTIVE_EXPERIMENTS, {"CATALOG_30_EXPERIMENT":{"name":"CATALOG_30_EXPERIMENT_V1_VARIANT_1","variant":"VARIANT_1","active":true,"props":{},"analytics":{"variant_id":"1","experiment_id":"cMqPkxoEQOaRL_twxbPBRA","media_query":"","disableEarlyAnalytics":false}}});} else {window.ACTIVE_EXPERIMENTS = {"CATALOG_30_EXPERIMENT":{"name":"CATALOG_30_EXPERIMENT_V1_VARIANT_1","variant":"VARIANT_1","active":true,"props":{},"analytics":{"variant_id":"1","experiment_id":"cMqPkxoEQOaRL_twxbPBRA","media_query":"","disableEarlyAnalytics":false}}};}</script><script src="assets/vendor/segment.js" async="" data-analytics-bootstrap=""></script>
# <link rel="stylesheet" href="styles.cd049525371f607387d9.css"><style ng-transition="iridium-us">html[_ngcontent-sc0] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc0], *[_ngcontent-sc0]::after, *[_ngcontent-sc0]::before {
#   box-sizing: inherit; }
#
# a[_ngcontent-sc0] {
#   color: darkviolet; }
#
# body[_ngcontent-sc0] {
#   color: #028bb1; }
#
# [_nghost-sc0] {
#   display: block;
#   position: relative; }
#
# span.snackbar__content[_ngcontent-sc0] {
#   margin: 0;
#   color: white; }
#
# span.snackbar__content[_ngcontent-sc0]   a[_ngcontent-sc0] {
#     margin: 0;
#     color: white;
#     text-decoration: underline; }
#
# ir-header[_ngcontent-sc0], ir-new-header[_ngcontent-sc0] {
#   position: relative;
#   z-index: 7000; }
#
# .sticky.isFixed[_nghost-sc0]   ir-header[_ngcontent-sc0], .sticky.isFixed   [_nghost-sc0]   ir-header[_ngcontent-sc0], .sticky.isFixed[_nghost-sc0]   ir-new-header[_ngcontent-sc0], .sticky.isFixed   [_nghost-sc0]   ir-new-header[_ngcontent-sc0] {
#   top: auto; }
#
# @media screen and (min-width: 48rem) {
#     .sticky.isFixed[_nghost-sc0]   ir-header[_ngcontent-sc0], .sticky.isFixed   [_nghost-sc0]   ir-header[_ngcontent-sc0], .sticky.isFixed[_nghost-sc0]   ir-new-header[_ngcontent-sc0], .sticky.isFixed   [_nghost-sc0]   ir-new-header[_ngcontent-sc0] {
#       top: 52px; } }</style><style ng-transition="iridium-us">html[_ngcontent-sc1] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc1], *[_ngcontent-sc1]::after, *[_ngcontent-sc1]::before {
#   box-sizing: inherit; }
#
# .invisible[_ngcontent-sc1] {
#   visibility: hidden !important; }
#
# .hide[_ngcontent-sc1] {
#   display: none !important; }
#
# .show[_ngcontent-sc1] {
#   display: block !important; }
#
# .sr-only[_ngcontent-sc1] {
#   height: 1px;
#   width: 1px;
#   overflow: hidden;
#   position: absolute !important;
#   clip: rect(1px, 1px, 1px, 1px); }
#
# .hidden-xs-up[_ngcontent-sc1] {
#   display: none !important; }
#
# @media (max-width: 479px) {
#   .hidden-xs-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 480px) {
#   .hidden-sm-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (max-width: 767px) {
#   .hidden-sm-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 768px) {
#   .hidden-md-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (max-width: 991px) {
#   .hidden-md-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 992px) {
#   .hidden-lg-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (max-width: 1179px) {
#   .hidden-lg-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 1180px) {
#   .hidden-xl-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# .hidden-xl-down[_ngcontent-sc1] {
#   display: none !important; }
#
# .visible-print-block[_ngcontent-sc1] {
#   display: none !important; }
#
# @media print {
#     .visible-print-block[_ngcontent-sc1] {
#       display: block !important; } }
#
# .visible-print-inline[_ngcontent-sc1] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline[_ngcontent-sc1] {
#       display: inline !important; } }
#
# .visible-print-inline-block[_ngcontent-sc1] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline-block[_ngcontent-sc1] {
#       display: inline-block !important; } }
#
# @media print {
#   .hidden-print[_ngcontent-sc1] {
#     display: none !important; } }
#
# #contain-all[_ngcontent-sc1] {
#   width: 100%;
#   overflow: hidden;
#   background: #fff;
#   -webkit-backface-visibility: hidden;
#           backface-visibility: hidden;
#   -webkit-transform-style: preserve-3d; }
#
# .outer_contain[_ngcontent-sc1] {
#   margin: 0 auto;
#   max-width: 90rem; }
#
# .contain[_ngcontent-sc1] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto;
#   padding-top: 3rem;
#   padding-bottom: 3rem;
#   padding-left: 1.5rem;
#   padding-right: 1.5rem; }
#
# .contain[_ngcontent-sc1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# @media screen and (min-width: 48rem) {
#
#     .contain[_ngcontent-sc1] {
#       padding-top: 6rem;
#       padding-bottom: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#
#     .contain[_ngcontent-sc1] {
#       padding-left: 0;
#       padding-right: 0; } }
#
# .contain.no-padding[_ngcontent-sc1] {
#     padding: 0; }
#
# .contain.no-padding-top[_ngcontent-sc1] {
#     padding-top: 0; }
#
# .contain.no-padding-bottom[_ngcontent-sc1] {
#     padding-bottom: 0; }
#
# .contain--none[_ngcontent-sc1] {
#     padding-top: 0rem;
#     padding-bottom: 0rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--none[_ngcontent-sc1] {
#         padding-top: 0rem;
#         padding-bottom: 0rem; } }
#
# .contain--small[_ngcontent-sc1] {
#     padding-top: 3rem;
#     padding-bottom: 3rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--small[_ngcontent-sc1] {
#         padding-top: 4.5rem;
#         padding-bottom: 4.5rem; } }
#
# .cards_contain[_ngcontent-sc1] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto; }
#
# .cards_contain[_ngcontent-sc1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# [_ngcontent-sc1]:-webkit-full-screen-ancestor {
#   -webkit-animation: none !important;
#           animation: none !important;
#   -webkit-animation-fill-mode: none !important;
#   animation-fill-mode: none !important; }
#
# [_ngcontent-sc1]:target:before {
#   content: '';
#   display: inline-block;
#   height: 130px;
#   margin: -130px 0 0; }
#
# .header[_ngcontent-sc1] {
#   max-width: 100%;
#   margin-left: auto;
#   margin-right: auto; }
#
# .header[_ngcontent-sc1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# .header.header--clone[_ngcontent-sc1] {
#     width: 100%;
#     top: -1000px; }
#
# .header.header--clone[_ngcontent-sc1]   .header__navbar[_ngcontent-sc1] {
#       height: 4.5rem; }
#
# .header.header--stick[_ngcontent-sc1] {
#     top: 0;
#     background-color: #fff;
#     z-index: 8000;
#     box-shadow: 0px 1px 2px rgba(0, 0, 0, 0.1); }
#
# .header__navbar[_ngcontent-sc1] {
#     max-width: 73.75rem;
#     margin-left: auto;
#     margin-right: auto;
#     height: 4.5rem;
#     padding: 0 1.5em; }
#
# .header__navbar[_ngcontent-sc1]::after {
#       clear: both;
#       content: "";
#       display: table; }
#
# @media screen and (min-width: 48rem) {
#       .header__navbar[_ngcontent-sc1] {
#         height: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#       .header__navbar[_ngcontent-sc1] {
#         padding: 0; } }
#
# .header__navbar--toggle[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 15.25423729%; }
#
# .header__navbar--toggle[_ngcontent-sc1]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--toggle[_ngcontent-sc1] {
#           display: none; } }
#
# .header__navbar--logo[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 66.10169492%; }
#
# .header__navbar--logo[_ngcontent-sc1]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc1] {
#           float: left;
#           display: block;
#           margin-right: 0.84033613%;
#           width: 20.16806723%; }
#           .header__navbar--logo[_ngcontent-sc1]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--catalog[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--catalog[_ngcontent-sc1] {
#           float: left;
#           display: block;
#           margin-right: 0.84033613%;
#           width: 7.56302521%; }
#           .header__navbar--catalog[_ngcontent-sc1]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--navigation[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--navigation[_ngcontent-sc1] {
#           float: left;
#           display: block;
#           margin-right: 1.69491525%;
#           width: 74.57627119%; }
#           .header__navbar--navigation[_ngcontent-sc1]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--logo[_ngcontent-sc1] {
#     text-align: center; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--logo[_ngcontent-sc1] {
#         text-align: left; } }
#
# .header__navbar--logo[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#       width: 11.25rem;
#       height: 1.875rem;
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#           display: block; } }
#
# .header__navbar--logo[_ngcontent-sc1]   .logo-mark[_ngcontent-sc1] {
#       display: block;
#       margin: 0 auto;
#       width: 1.875rem;
#       height: 1.875rem; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc1]   .logo-mark[_ngcontent-sc1] {
#           display: none; } }
#
# .header__navbar--toggle[_ngcontent-sc1]   .nav-toggle[_ngcontent-sc1] {
#     display: block;
#     width: 1.25rem;
#     height: 1.25rem;
#     cursor: pointer;
#     transition: -webkit-transform .25s ease;
#     transition: transform .25s ease;
#     transition: transform .25s ease, -webkit-transform .25s ease; }
#
# .header__navbar--toggle[_ngcontent-sc1]   .nav-toggle[_ngcontent-sc1]   .bar[_ngcontent-sc1] {
#       display: block;
#       width: 100%;
#       height: 0.1875rem;
#       margin-left: -0.5rem;
#       margin-top: 0.1875rem;
#       background: #02b3e4;
#       transition: opacity .25s ease, -webkit-transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease, -webkit-transform .25s ease;
#       -webkit-user-select: none;
#          -moz-user-select: none;
#           -ms-user-select: none;
#               user-select: none; }
#
# .header__navbar--navigation[_ngcontent-sc1]   nav[_ngcontent-sc1] {
#     float: right; }
#
# .header__navbar--navigation[_ngcontent-sc1]   a[_ngcontent-sc1], .header__navbar--navigation[_ngcontent-sc1]   div[_ngcontent-sc1] {
#     float: left; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button[_ngcontent-sc1] {
#     display: none;
#     letter-spacing: 0;
#     font-size: 0.875rem;
#     text-transform: capitalize;
#     height: 2.25rem;
#     font-weight: 400;
#     margin-left: 2.5rem;
#     line-height: 1.9375rem; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button[_ngcontent-sc1]:first-child {
#       margin-left: 0; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--navigation[_ngcontent-sc1]   .button[_ngcontent-sc1] {
#         display: block; } }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--navigation[_ngcontent-sc1] {
#       padding: 0;
#       color: #525c65; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--navigation[_ngcontent-sc1]:hover {
#         color: #474f57; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--primary[_ngcontent-sc1], .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1] {
#       width: 7.75rem;
#       box-shadow: 8px 10px 20px 0px rgba(46, 61, 73, 0.15);
#       background-color: #02b3e4; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--primary[_ngcontent-sc1]:hover, .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1]:hover {
#         box-shadow: 2px 4px 8px 0px rgba(46, 61, 73, 0.2);
#         background-color: #02b7e9; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1] {
#       background-color: #02ccba; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1]:hover {
#         background-color: #02d1bf; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--guest[_ngcontent-sc1], .header__navbar--navigation[_ngcontent-sc1]   .button--student[_ngcontent-sc1] {
#       display: none; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .divider[_ngcontent-sc1] {
#     cursor: default; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .divider[_ngcontent-sc1]::before {
#       content: '';
#       border-left: 1px solid rgba(82, 92, 101, 0.4);
#       width: 0px;
#       height: 12px; }
#
# .header__sidenav[_ngcontent-sc1] {
#     background-color: #2e3d49; }
#
# .header__sidenav--logo[_ngcontent-sc1] {
#       height: 4.5rem;
#       display: block;
#       background-color: #1C262F; }
#
# .header__sidenav--logo[_ngcontent-sc1]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--logo[_ngcontent-sc1]   .logo-link[_ngcontent-sc1] {
#         display: block;
#         width: 100%;
#         height: 100%; }
#
# .header__sidenav--logo[_ngcontent-sc1]   .logo-link[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#           position: relative;
#           top: 50%;
#           -webkit-transform: translateY(-50%);
#           transform: translateY(-50%);
#           padding-left: 1.5em;
#           width: 11.25rem;
#           height: 1.875rem; }
#
# .header__sidenav--logo[_ngcontent-sc1]   .logo-link[_ngcontent-sc1]   #wordmark[_ngcontent-sc1] {
#           fill: #fff; }
#
# .header__sidenav--navigation[_ngcontent-sc1] {
#       display: block; }
#
# .header__sidenav--navigation[_ngcontent-sc1]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   li[_ngcontent-sc1] {
#         height: 4.5rem; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   a[_ngcontent-sc1] {
#         padding-top: 1.5rem;
#         padding-bottom: 1.5rem;
#         color: #fff;
#         display: block;
#         padding-left: 1.5em; }
#
# @media screen and (min-width: 48rem) {
#           .header__sidenav--navigation[_ngcontent-sc1]   a[_ngcontent-sc1] {
#             padding-top: 1.5rem;
#             padding-bottom: 1.5rem; } }
#
# .header__sidenav--navigation[_ngcontent-sc1]   a[_ngcontent-sc1]:hover {
#           color: #cccccc; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   .guest[_ngcontent-sc1], .header__sidenav--navigation[_ngcontent-sc1]   .student[_ngcontent-sc1] {
#         display: none; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   .guest[_ngcontent-sc1]   a[_ngcontent-sc1], .header__sidenav--navigation[_ngcontent-sc1]   .student[_ngcontent-sc1]   a[_ngcontent-sc1] {
#           color: #02b3e4; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   .guest[_ngcontent-sc1]   a[_ngcontent-sc1]:hover, .header__sidenav--navigation[_ngcontent-sc1]   .student[_ngcontent-sc1]   a[_ngcontent-sc1]:hover {
#             color: #01647f; }
#
# [_nghost-sc1] {
#   background: #2e3d49;
#   position: fixed;
#   top: 0;
#   left: 0;
#   height: 100vh;
#   display: block;
#   overflow-y: auto;
#   z-index: -1000;
#   width: 16.25rem;
#   -webkit-overflow-scrolling: touch;
#   display: block; }
#
# @media screen and (min-width: 62rem) {
#     [_nghost-sc1] {
#       display: none; } }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1] {
#     height: 4.5rem;
#     display: block;
#     background-color: #1C262F; }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1]::after {
#       clear: both;
#       content: "";
#       display: table; }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       padding-left: 1.5em;
#       width: 11.25rem;
#       height: 1.875rem; }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1]   #wordmark[_ngcontent-sc1] {
#       fill: #fff; }
#
# [_nghost-sc1]   ul[_ngcontent-sc1] {
#     list-style: none;
#     padding: 0; }
#
# .page-lg[_nghost-sc1], .page-lg   [_nghost-sc1] {
#   display: none; }</style><style ng-transition="iridium-us">html[_ngcontent-sc2] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc2], *[_ngcontent-sc2]::after, *[_ngcontent-sc2]::before {
#   box-sizing: inherit; }
#
# [_nghost-sc2] {
#   position: absolute;
#   width: 100%;
#   top: 0;
#   left: 0;
#   min-height: 100vh;
#   z-index: 0;
#   transition: -webkit-transform 0.3s ease;
#   transition: transform 0.3s ease;
#   transition: transform 0.3s ease, -webkit-transform 0.3s ease;
#   background: #fff; }
#
# .menu--open[_nghost-sc2]:not(.nav-experiment), .menu--open:not(.nav-experiment)   [_nghost-sc2] {
#   -webkit-transform: translateX(16.25rem);
#           transform: translateX(16.25rem); }
#
# .menu--open[_nghost-sc2], .menu--open   [_nghost-sc2] {
#   height: 100vh;
#   overflow: hidden; }
#
# @media screen and (min-width: 62rem) {
#     .menu--open[_nghost-sc2], .menu--open   [_nghost-sc2] {
#       overflow: auto;
#       -webkit-transform: none;
#               transform: none;
#       height: auto; } }
#
# .sticky[_nghost-sc2]:not(.no-sticky-header), .sticky:not(.no-sticky-header)   [_nghost-sc2] {
#   padding-top: 4.5rem; }
#
# @media screen and (min-width: 48rem) {
#     .sticky[_nghost-sc2]:not(.no-sticky-header), .sticky:not(.no-sticky-header)   [_nghost-sc2] {
#       padding-top: 6rem; } }
#
# .page-cn.page-school-of-data-science[_nghost-sc2], .page-cn.page-school-of-data-science   [_nghost-sc2] {
#   padding-top: 0; }
#
# .page-riseup[_nghost-sc2], .page-riseup   [_nghost-sc2] {
#   background: #2e3d49; }</style><style ng-transition="iridium-us">html[_ngcontent-sc3] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc3], *[_ngcontent-sc3]::after, *[_ngcontent-sc3]::before {
#   box-sizing: inherit; }
#
# [_nghost-sc3] {
#   display: block;
#   overflow: hidden; }
#
# .moustache[_ngcontent-sc3] {
#   position: relative;
#   width: 100%;
#   background: #fff;
#   padding: 0.75rem 2.5rem 0.75rem 1.5rem;
#   color: #fff;
#   text-align: center;
#   z-index: 8999; }
#
# .moustache[_ngcontent-sc3]   p[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     border-bottom: none; }
#
# .moustache[_ngcontent-sc3]   p[_ngcontent-sc3]   a.moustache__link--button[_ngcontent-sc3] {
#       border-bottom: 1px solid;
#       margin: 0 0.8rem; }
#
# .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #02b3e4;
#     display: inline-block;
#     margin: 0; }
#
# .moustache[_ngcontent-sc3]   .close-btn[_ngcontent-sc3] {
#     position: absolute;
#     top: 0;
#     right: 1rem;
#     bottom: 0;
#     display: flex;
#     background-color: transparent;
#     border: none;
#     outline: none;
#     opacity: 0.75;
#     margin: auto 0;
#     padding: 0;
#     color: #fff;
#     transition: opacity 0.3s ease; }
#
# .moustache[_ngcontent-sc3]   .close-btn[_ngcontent-sc3]   svg[_ngcontent-sc3] {
#       height: 0.8rem;
#       width: auto; }
#
# .moustache[_ngcontent-sc3]   .close-btn[_ngcontent-sc3]:hover {
#       opacity: 1; }
#
# .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #02b3e4; }
#
# .moustache.white[_ngcontent-sc3] {
#     background: #fff; }
#
# .moustache.white[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.white[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #02b3e4;
#       font-size: 1rem; }
#
# .moustache.white[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #02b3e4; }
#
# .moustache.blue[_ngcontent-sc3] {
#     background: #02b3e4; }
#
# .moustache.blue[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.blue[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.blue[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.blue-turquoise[_ngcontent-sc3] {
#     background: linear-gradient(to right, #02b3e4, #02ccba); }
#
# .moustache.blue-turquoise[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.blue-turquoise[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.blue-turquoise[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.purple-turquoise[_ngcontent-sc3] {
#     background: linear-gradient(to right, #a951ed, #02ccba); }
#
# .moustache.purple-turquoise[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.purple-turquoise[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.purple-turquoise[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.magenta-yellow[_ngcontent-sc3] {
#     background: linear-gradient(to right, #ff5483, #ffae0c); }
#
# .moustache.magenta-yellow[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.magenta-yellow[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.magenta-yellow[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.yellow-purple[_ngcontent-sc3] {
#     background: linear-gradient(to right, #ffae0c, #a951ed); }
#
# .moustache.yellow-purple[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.yellow-purple[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.yellow-purple[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.yellow-on-black[_ngcontent-sc3] {
#     background: #000; }
#
# .moustache.yellow-on-black[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.yellow-on-black[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #ffae0c;
#       font-size: 1rem; }
#
# .moustache.yellow-on-black[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #ffae0c; }
#
# .page-in.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-corporate[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-corporate   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-campaign[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-campaign   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-google-india-scholarships[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-google-india-scholarships   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-ucollege[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-ucollege   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   display: none; }
#
# .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   background: #02b3e4; }
#
# .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #fff;
#     font-size: 1rem; }
#
# .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #fff; }
#
# .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   background: #fff; }
#
# .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #02b3e4;
#     font-size: 1rem; }
#
# .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #02b3e4; }
#
# .page-cn.page-homepage.sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   background: #02b3e4; }
#
# .page-cn.page-homepage.sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #fff;
#     font-size: 1rem; }
#
# .page-cn.page-homepage.sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #fff; }
#
# .sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3], .sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   position: fixed;
#   z-index: 8001;
#   top: 0; }
#
# .page-cn.page-20181111[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn.page-20181111   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   display: none; }</style><style ng-transition="iridium-us">html[_ngcontent-sc4] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc4], *[_ngcontent-sc4]::after, *[_ngcontent-sc4]::before {
#   box-sizing: inherit; }
#
# .invisible[_ngcontent-sc4] {
#   visibility: hidden !important; }
#
# .hide[_ngcontent-sc4] {
#   display: none !important; }
#
# .show[_ngcontent-sc4] {
#   display: block !important; }
#
# .sr-only[_ngcontent-sc4] {
#   height: 1px;
#   width: 1px;
#   overflow: hidden;
#   position: absolute !important;
#   clip: rect(1px, 1px, 1px, 1px); }
#
# .hidden-xs-up[_ngcontent-sc4] {
#   display: none !important; }
#
# @media (max-width: 479px) {
#   .hidden-xs-down[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (min-width: 480px) {
#   .hidden-sm-up[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (max-width: 767px) {
#   .hidden-sm-down[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (min-width: 768px) {
#   .hidden-md-up[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (max-width: 991px) {
#   .hidden-md-down[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (min-width: 992px) {
#   .hidden-lg-up[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (max-width: 1179px) {
#   .hidden-lg-down[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (min-width: 1180px) {
#   .hidden-xl-up[_ngcontent-sc4] {
#     display: none !important; } }
#
# .hidden-xl-down[_ngcontent-sc4] {
#   display: none !important; }
#
# .visible-print-block[_ngcontent-sc4] {
#   display: none !important; }
#
# @media print {
#     .visible-print-block[_ngcontent-sc4] {
#       display: block !important; } }
#
# .visible-print-inline[_ngcontent-sc4] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline[_ngcontent-sc4] {
#       display: inline !important; } }
#
# .visible-print-inline-block[_ngcontent-sc4] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline-block[_ngcontent-sc4] {
#       display: inline-block !important; } }
#
# @media print {
#   .hidden-print[_ngcontent-sc4] {
#     display: none !important; } }
#
# #contain-all[_ngcontent-sc4] {
#   width: 100%;
#   overflow: hidden;
#   background: #fff;
#   -webkit-backface-visibility: hidden;
#           backface-visibility: hidden;
#   -webkit-transform-style: preserve-3d; }
#
# .outer_contain[_ngcontent-sc4] {
#   margin: 0 auto;
#   max-width: 90rem; }
#
# .contain[_ngcontent-sc4] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto;
#   padding-top: 3rem;
#   padding-bottom: 3rem;
#   padding-left: 1.5rem;
#   padding-right: 1.5rem; }
#
# .contain[_ngcontent-sc4]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# @media screen and (min-width: 48rem) {
#
#     .contain[_ngcontent-sc4] {
#       padding-top: 6rem;
#       padding-bottom: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#
#     .contain[_ngcontent-sc4] {
#       padding-left: 0;
#       padding-right: 0; } }
#
# .contain.no-padding[_ngcontent-sc4] {
#     padding: 0; }
#
# .contain.no-padding-top[_ngcontent-sc4] {
#     padding-top: 0; }
#
# .contain.no-padding-bottom[_ngcontent-sc4] {
#     padding-bottom: 0; }
#
# .contain--none[_ngcontent-sc4] {
#     padding-top: 0rem;
#     padding-bottom: 0rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--none[_ngcontent-sc4] {
#         padding-top: 0rem;
#         padding-bottom: 0rem; } }
#
# .contain--small[_ngcontent-sc4] {
#     padding-top: 3rem;
#     padding-bottom: 3rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--small[_ngcontent-sc4] {
#         padding-top: 4.5rem;
#         padding-bottom: 4.5rem; } }
#
# .cards_contain[_ngcontent-sc4] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto; }
#
# .cards_contain[_ngcontent-sc4]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# [_ngcontent-sc4]:-webkit-full-screen-ancestor {
#   -webkit-animation: none !important;
#           animation: none !important;
#   -webkit-animation-fill-mode: none !important;
#   animation-fill-mode: none !important; }
#
# [_ngcontent-sc4]:target:before {
#   content: '';
#   display: inline-block;
#   height: 130px;
#   margin: -130px 0 0; }
#
# .header[_ngcontent-sc4], [_nghost-sc4] {
#   max-width: 100%;
#   margin-left: auto;
#   margin-right: auto; }
#
# .header[_ngcontent-sc4]::after, [_nghost-sc4]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# .header.header--clone[_ngcontent-sc4], .header--clone[_nghost-sc4] {
#     width: 100%;
#     top: -1000px; }
#
# .header.header--clone[_ngcontent-sc4]   .header__navbar[_ngcontent-sc4], .header--clone[_nghost-sc4]   .header__navbar[_ngcontent-sc4], .header.header--clone[_ngcontent-sc4]   header[_ngcontent-sc4], .header--clone[_nghost-sc4]   header[_ngcontent-sc4] {
#       height: 4.5rem; }
#
# .header.header--stick[_ngcontent-sc4], .header--stick[_nghost-sc4] {
#     top: 0;
#     background-color: #fff;
#     z-index: 8000;
#     box-shadow: 0px 1px 2px rgba(0, 0, 0, 0.1); }
#
# .header__navbar[_ngcontent-sc4], header[_ngcontent-sc4] {
#     max-width: 73.75rem;
#     margin-left: auto;
#     margin-right: auto;
#     height: 4.5rem;
#     padding: 0 1.5em; }
#
# .header__navbar[_ngcontent-sc4]::after, header[_ngcontent-sc4]::after {
#       clear: both;
#       content: "";
#       display: table; }
#
# @media screen and (min-width: 48rem) {
#       .header__navbar[_ngcontent-sc4], header[_ngcontent-sc4] {
#         height: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#       .header__navbar[_ngcontent-sc4], header[_ngcontent-sc4] {
#         padding: 0; } }
#
# .header__navbar--toggle[_ngcontent-sc4] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 15.25423729%; }
#
# .header__navbar--toggle[_ngcontent-sc4]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--toggle[_ngcontent-sc4] {
#           display: none; } }
#
# .header__navbar--logo[_ngcontent-sc4] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 66.10169492%; }
#
# .header__navbar--logo[_ngcontent-sc4]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc4] {
#           float: left;
#           display: block;
#           margin-right: 0.84033613%;
#           width: 20.16806723%; }
#           .header__navbar--logo[_ngcontent-sc4]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--catalog[_ngcontent-sc4] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--catalog[_ngcontent-sc4] {
#           float: left;
#           display: block;
#           margin-right: 0.84033613%;
#           width: 7.56302521%; }
#           .header__navbar--catalog[_ngcontent-sc4]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--navigation[_ngcontent-sc4] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--navigation[_ngcontent-sc4] {
#           float: left;
#           display: block;
#           margin-right: 1.69491525%;
#           width: 74.57627119%; }
#           .header__navbar--navigation[_ngcontent-sc4]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--logo[_ngcontent-sc4] {
#     text-align: center; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--logo[_ngcontent-sc4] {
#         text-align: left; } }
#
# .header__navbar--logo[_ngcontent-sc4]   .logo-wordmark[_ngcontent-sc4], .header__navbar--logo[_ngcontent-sc4]   .logo-wordmark--cn[_ngcontent-sc4] {
#       width: 11.25rem;
#       height: 1.875rem;
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc4]   .logo-wordmark[_ngcontent-sc4], .header__navbar--logo[_ngcontent-sc4]   .logo-wordmark--cn[_ngcontent-sc4] {
#           display: block; } }
#
# .header__navbar--logo[_ngcontent-sc4]   .logo-mark[_ngcontent-sc4] {
#       display: block;
#       margin: 0 auto;
#       width: 1.875rem;
#       height: 1.875rem; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc4]   .logo-mark[_ngcontent-sc4] {
#           display: none; } }
#
# .header__navbar--toggle[_ngcontent-sc4]   .nav-toggle[_ngcontent-sc4] {
#     display: block;
#     width: 1.25rem;
#     height: 1.25rem;
#     cursor: pointer;
#     transition: -webkit-transform .25s ease;
#     transition: transform .25s ease;
#     transition: transform .25s ease, -webkit-transform .25s ease; }
#
# .header__navbar--toggle[_ngcontent-sc4]   .nav-toggle[_ngcontent-sc4]   .bar[_ngcontent-sc4] {
#       display: block;
#       width: 100%;
#       height: 0.1875rem;
#       margin-left: -0.5rem;
#       margin-top: 0.1875rem;
#       background: #02b3e4;
#       transition: opacity .25s ease, -webkit-transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease, -webkit-transform .25s ease;
#       -webkit-user-select: none;
#          -moz-user-select: none;
#           -ms-user-select: none;
#               user-select: none; }
#
# .header__navbar--navigation[_ngcontent-sc4]   nav[_ngcontent-sc4] {
#     float: right; }
#
# .header__navbar--navigation[_ngcontent-sc4]   a[_ngcontent-sc4], .header__navbar--navigation[_ngcontent-sc4]   div[_ngcontent-sc4] {
#     float: left; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button[_ngcontent-sc4] {
#     display: none;
#     letter-spacing: 0;
#     font-size: 0.875rem;
#     text-transform: capitalize;
#     height: 2.25rem;
#     font-weight: 400;
#     margin-left: 2.5rem;
#     line-height: 1.9375rem; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button[_ngcontent-sc4]:first-child {
#       margin-left: 0; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--navigation[_ngcontent-sc4]   .button[_ngcontent-sc4] {
#         display: block; } }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--navigation[_ngcontent-sc4] {
#       padding: 0;
#       color: #525c65; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--navigation[_ngcontent-sc4]:hover {
#         color: #474f57; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--primary[_ngcontent-sc4], .header__navbar--navigation[_ngcontent-sc4]   .button--turquoise[_ngcontent-sc4] {
#       width: 7.75rem;
#       box-shadow: 8px 10px 20px 0px rgba(46, 61, 73, 0.15);
#       background-color: #02b3e4; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--primary[_ngcontent-sc4]:hover, .header__navbar--navigation[_ngcontent-sc4]   .button--turquoise[_ngcontent-sc4]:hover {
#         box-shadow: 2px 4px 8px 0px rgba(46, 61, 73, 0.2);
#         background-color: #02b7e9; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--turquoise[_ngcontent-sc4] {
#       background-color: #02ccba; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--turquoise[_ngcontent-sc4]:hover {
#         background-color: #02d1bf; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--guest[_ngcontent-sc4], .header__navbar--navigation[_ngcontent-sc4]   .button--student[_ngcontent-sc4] {
#       display: none; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .divider[_ngcontent-sc4] {
#     cursor: default; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .divider[_ngcontent-sc4]::before {
#       content: '';
#       border-left: 1px solid rgba(82, 92, 101, 0.4);
#       width: 0px;
#       height: 12px; }
#
# .header__sidenav[_ngcontent-sc4] {
#     background-color: #2e3d49; }
#
# .header__sidenav--logo[_ngcontent-sc4] {
#       height: 4.5rem;
#       display: block;
#       background-color: #1C262F; }
#
# .header__sidenav--logo[_ngcontent-sc4]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--logo[_ngcontent-sc4]   .logo-link[_ngcontent-sc4] {
#         display: block;
#         width: 100%;
#         height: 100%; }
#
# .header__sidenav--logo[_ngcontent-sc4]   .logo-link[_ngcontent-sc4]   .logo-wordmark[_ngcontent-sc4], .header__sidenav--logo[_ngcontent-sc4]   .logo-link[_ngcontent-sc4]   .logo-wordmark--cn[_ngcontent-sc4] {
#           position: relative;
#           top: 50%;
#           -webkit-transform: translateY(-50%);
#           transform: translateY(-50%);
#           padding-left: 1.5em;
#           width: 11.25rem;
#           height: 1.875rem; }
#
# .header__sidenav--logo[_ngcontent-sc4]   .logo-link[_ngcontent-sc4]   #wordmark[_ngcontent-sc4] {
#           fill: #fff; }
#
# .header__sidenav--navigation[_ngcontent-sc4] {
#       display: block; }
#
# .header__sidenav--navigation[_ngcontent-sc4]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   li[_ngcontent-sc4] {
#         height: 4.5rem; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   a[_ngcontent-sc4] {
#         padding-top: 1.5rem;
#         padding-bottom: 1.5rem;
#         color: #fff;
#         display: block;
#         padding-left: 1.5em; }
#
# @media screen and (min-width: 48rem) {
#           .header__sidenav--navigation[_ngcontent-sc4]   a[_ngcontent-sc4] {
#             padding-top: 1.5rem;
#             padding-bottom: 1.5rem; } }
#
# .header__sidenav--navigation[_ngcontent-sc4]   a[_ngcontent-sc4]:hover {
#           color: #cccccc; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   .guest[_ngcontent-sc4], .header__sidenav--navigation[_ngcontent-sc4]   .student[_ngcontent-sc4] {
#         display: none; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   .guest[_ngcontent-sc4]   a[_ngcontent-sc4], .header__sidenav--navigation[_ngcontent-sc4]   .student[_ngcontent-sc4]   a[_ngcontent-sc4] {
#           color: #02b3e4; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   .guest[_ngcontent-sc4]   a[_ngcontent-sc4]:hover, .header__sidenav--navigation[_ngcontent-sc4]   .student[_ngcontent-sc4]   a[_ngcontent-sc4]:hover {
#             color: #01647f; }
#
# html[_ngcontent-sc4] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc4], *[_ngcontent-sc4]::after, *[_ngcontent-sc4]::before {
#   box-sizing: inherit; }
#
# [_nghost-sc4] {
#   display: block;
#   z-index: 1;
#   position: relative; }
#
# header[_ngcontent-sc4]   .header__navbar--navigation[_ngcontent-sc4] {
#   float: right; }
#
# @-webkit-keyframes sticky-slide-down {
#   100% {
#     -webkit-transform: translateY(0);
#             transform: translateY(0); } }
#
# @keyframes sticky-slide-down {
#   100% {
#     -webkit-transform: translateY(0);
#             transform: translateY(0); } }
#
# .header-icons[_ngcontent-sc4] {
#   display: block;
#   position: relative;
#   top: 1.4rem;
#   float: right;
#   margin-right: -0.7rem; }
#
# .header-icons[_ngcontent-sc4]   svg[_ngcontent-sc4] {
#     height: 1.8rem;
#     fill: #02b3e4; }
#
# @media screen and (min-width: 30rem) {
#     .header-icons[_ngcontent-sc4] {
#       display: none; } }
#
# .phone-icon[_ngcontent-sc4] {
#   display: none;
#   line-height: 0; }
#
# .show-sales-widget[_nghost-sc4]   .phone-icon[_ngcontent-sc4], .show-sales-widget   [_nghost-sc4]   .phone-icon[_ngcontent-sc4] {
#   display: block;
#   position: relative;
#   top: 1.4rem;
#   float: right;
#   margin-right: -0.7rem;
#   top: 50%;
#   -webkit-transform: translateY(-50%);
#           transform: translateY(-50%); }
#
# .show-sales-widget[_nghost-sc4]   .phone-icon[_ngcontent-sc4]   svg[_ngcontent-sc4], .show-sales-widget   [_nghost-sc4]   .phone-icon[_ngcontent-sc4]   svg[_ngcontent-sc4] {
#     height: 1.8rem;
#     fill: #02b3e4; }
#
# @media screen and (min-width: 30rem) {
#     .show-sales-widget[_nghost-sc4]   .phone-icon[_ngcontent-sc4], .show-sales-widget   [_nghost-sc4]   .phone-icon[_ngcontent-sc4] {
#       display: none; } }
#
# .page-homepage[_nghost-sc4]   .logo-wordmark[_ngcontent-sc4]   h1[_ngcontent-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-homepage   [_nghost-sc4]   .logo-wordmark[_ngcontent-sc4]   h1[_ngcontent-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-homepage[_nghost-sc4]   .logo-wordmark--cn[_ngcontent-sc4]   h1[_ngcontent-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-homepage   [_nghost-sc4]   .logo-wordmark--cn[_ngcontent-sc4]   h1[_ngcontent-sc4]   img.logo-wordmark--img[_ngcontent-sc4] {
#   padding-bottom: 1.5rem;
#   width: 180px; }
#
# .page-homepage[_nghost-sc4]   .logo-wordmark--cn[_ngcontent-sc4]   h1[_ngcontent-sc4], .page-homepage   [_nghost-sc4]   .logo-wordmark--cn[_ngcontent-sc4]   h1[_ngcontent-sc4] {
#   margin-bottom: 0; }
#
# .page-eu.page-homepage[_nghost-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-eu.page-homepage   [_nghost-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-in.page-homepage[_nghost-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-in.page-homepage   [_nghost-sc4]   img.logo-wordmark--img[_ngcontent-sc4] {
#   padding-bottom: 1.5rem; }
#
# ...
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="react-native"><label _ngcontent-sc344="" class="item" for="react-native" htmlfor="react-native"> React Native
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="redux"><label _ngcontent-sc344="" class="item" for="redux" htmlfor="redux"> Redux
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="robot-operating system"><label _ngcontent-sc344="" class="item" for="robot-operating system" htmlfor="robot-operating system"> Robot Operating System
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="robotics"><label _ngcontent-sc344="" class="item" for="robotics" htmlfor="robotics"> Robotics
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="sql"><label _ngcontent-sc344="" class="item" for="sql" htmlfor="sql"> SQL
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="search-ads"><label _ngcontent-sc344="" class="item" for="search-ads" htmlfor="search-ads"> Search Ads
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="search-algorithms"><label _ngcontent-sc344="" class="item" for="search-algorithms" htmlfor="search-algorithms"> Search Algorithms
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="self-driving-cars"><label _ngcontent-sc344="" class="item" for="self-driving-cars" htmlfor="self-driving-cars"> Self-Driving Cars
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="social-media marketing"><label _ngcontent-sc344="" class="item" for="social-media marketing" htmlfor="social-media marketing"> Social Media Marketing
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="statistics"><label _ngcontent-sc344="" class="item" for="statistics" htmlfor="statistics"> Statistics
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="supervised-learning"><label _ngcontent-sc344="" class="item" for="supervised-learning" htmlfor="supervised-learning"> Supervised Learning
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="swift-programming"><label _ngcontent-sc344="" class="item" for="swift-programming" htmlfor="swift-programming"> Swift programming
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="tableau"><label _ngcontent-sc344="" class="item" for="tableau" htmlfor="tableau"> Tableau
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="uikit"><label _ngcontent-sc344="" class="item" for="uikit" htmlfor="uikit"> UIKit
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="unity"><label _ngcontent-sc344="" class="item" for="unity" htmlfor="unity"> Unity
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="unity-arkit plugin"><label _ngcontent-sc344="" class="item" for="unity-arkit plugin" htmlfor="unity-arkit plugin"> Unity ARKit Plugin
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="unreal"><label _ngcontent-sc344="" class="item" for="unreal" htmlfor="unreal"> Unreal
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="unsupervised-learning"><label _ngcontent-sc344="" class="item" for="unsupervised-learning" htmlfor="unsupervised-learning"> Unsupervised Learning
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="user-testing"><label _ngcontent-sc344="" class="item" for="user-testing" htmlfor="user-testing"> User testing
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="vr-development"><label _ngcontent-sc344="" class="item" for="vr-development" htmlfor="vr-development"> VR development
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="web-tooling and automation"><label _ngcontent-sc344="" class="item" for="web-tooling and automation" htmlfor="web-tooling and automation"> Web Tooling and Automation
# </label></ir-catalog-dropdown-filter-item></li><li _ngcontent-sc342="" class="ng-star-inserted"><ir-catalog-dropdown-filter-item _ngcontent-sc342="" _nghost-sc344=""><input _ngcontent-sc344="" name="name" type="checkbox" id="youtube-marketing"><label _ngcontent-sc344="" class="item" for="youtube-marketing" htmlfor="youtube-marketing"> YouTube Marketing
# </label></ir-catalog-dropdown-filter-item></li></ul><div _ngcontent-sc342="" class="filter__actions"><button _ngcontent-sc342="" class="filter__action"> Clear </button></div></div></div></ir-catalog-dropdown-filter><!----></div></div></div></div></div><!----><div _ngcontent-sc265="" class="catalog__cards__container contain ng-star-inserted"><div _ngcontent-sc265="" class="catalog__resultstext"> 229 <!----><!----><!----><!---->results</div><!----><div _ngcontent-sc265="" class="catalog__cards ng-star-inserted"><!----><!----><ir-catalog-nd-card _ngcontent-sc265="" class="catalog__cards-item ng-star-inserted" _nghost-sc343=""><div _ngcontent-sc343="" class="card card--red"><!----><main _ngcontent-sc343="" class="card__content ng-star-inserted"><!----><div _ngcontent-sc343="" class="card__rating ng-star-inserted" style="visibility:visibility;"><div _ngcontent-sc343="" class="card__stars"><div _ngcontent-sc343="" class="card__stars__fill" style="width:92.0949720670391%;"></div></div><span _ngcontent-sc343="" class="card__stars__count">(2148)</span></div><!----><div _ngcontent-sc343="" class="card__image dimmed ng-star-inserted" style="background-image:url(https://d20vrrgs8k4bvw.cloudfront.net/images/degrees/nd000/nd-card.jpg);"></div><!----><div _ngcontent-sc343="" class="card__tag"><!----></div><!----><div _ngcontent-sc343="" class="card__container"><div _ngcontent-sc343="" class="card__overlay"><!----><div _ngcontent-sc343="" class="card__rating ng-star-inserted" style="visibility:visibility;"><div _ngcontent-sc343="" class="card__stars"><div _ngcontent-sc343="" class="card__stars__fill" style="width:92.0949720670391%;"></div></div><span _ngcontent-sc343="" class="card__stars__count">(2148)</span></div><span _ngcontent-sc343="" class="card__overlay__enrollBy"><!----><!---->Enroll by November 14</span><!----><div _ngcontent-sc343="" class="card__overlay__summary ng-star-inserted">Udacity's Intro to Programming is your first step towards careers in Web and App Development, Machine Learning, Data Science, AI, and more! This program is perfect for beginners.</div><div _ngcontent-sc343="" class="card__collaboration"><!----></div></div><header _ngcontent-sc343="" class="card__header"><h2 _ngcontent-sc343="" class="card__school">School of Programming</h2><h1 _ngcontent-sc343="" class="card__title">Introduction to Programming</h1></header><!----><section _ngcontent-sc343="" class="card__concepts ng-star-inserted"><h6 _ngcontent-sc343="">Concepts Covered</h6><p _ngcontent-sc343="">Introduction to Programming, HTML, CSS, Python</p></section><div _ngcontent-sc343="" class="card__collaboration card__collaboration--mobile"><!----></div></div></main><section _ngcontent-sc343="" class="card__level ng-star-inserted" data-level="beginner"><svg _ngcontent-sc343="" xmlns:xlink="http://www.w3.org/1999/xlink" height="12px" version="1.1" viewBox="0 0 12 12" width="12px" xmlns="http://www.w3.org/2000/svg"><g _ngcontent-sc343="" fill="#647381"><rect _ngcontent-sc343="" height="12" width="2.4" x="9.6" y="0" style="opacity:0.5;"></rect><rect _ngcontent-sc343="" height="9.6" width="2.4" x="4.8" y="2.4" style="opacity:0.5;"></rect><rect _ngcontent-sc343="" height="7.2" width="2.4" x="0" y="4.8" style="opacity:1;"></rect></g></svg> beginner </section><footer _ngcontent-sc343="" class="card__footer ng-star-inserted"><div _ngcontent-sc343="" class="card__price"><!----><span _ngcontent-sc343="" class="ng-star-inserted">$599 USD</span><!----></div><button _ngcontent-sc343="" class="card__button">Learn More</button></footer><!----></div></ir-catalog-nd-card><ir-catalog-nd-card _ngcontent-sc265="" class="catalog__cards-item ng-star-inserted" _nghost-sc343=""><div _ngcontent-sc343="" class="card card--red"><!----><main _ngcontent-sc343="" class="card__content ng-star-inserted"><!----><div _ngcontent-sc343="" class="card__rating ng-star-inserted" style="visibility:hidden;"><div _ngcontent-sc343="" class="card__stars"><div _ngcontent-sc343="" class="card__stars__fill ...
# <script type="text/javascript" src="runtime.ba5ea5387c29ed57e6f5.js"></script><script type="text/javascript" src="polyfills.ccfa850a0d710421501f.js"></script><script type="text/javascript" src="scripts.0ff312eb31880c12aac8.js"></script><script type="text/javascript" src="main.c07d084d0124c9c4276f.js"></script>
#
# <script id="iridium-us-state" type="application/json">{&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerSpecialUrlLinks&a;locale=en-US&q;:[{&q;url&q;:&q;/built-on-blockchain&q;,&q;links&q;:[{&q;text&q;:&q;Home&q;,&q;href&q;:&q;/built-on-blockchain&q;},{&q;text&q;:&q;About&q;,&q;href&q;:&q;/built-on-blockchain/about&q;}]}],&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavLinks&a;locale=en-US&q;:[{&q;href&q;:&q;/courses/all&q;,&q;text&q;:&q;Catalog&q;},{&q;href&q;:&q;/pathfinder&q;,&q;text&q;:&q;Paths&q;},{&q;href&q;:&q;/nanodegree&q;,&q;text&q;:&q;Nanodegree&q;},{&q;href&q;:&q;/career-services&q;,&q;text&q;:&q;Career Help&q;},{&q;href&q;:&q;/enterprise&q;,&q;text&q;:&q;For Enterprise&q;}],&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavAuthMobileLinks&a;locale=en-US&q;:{&q;isAuth&q;:[{&q;text&q;:&q;Blog&q;,&q;href&q;:&q;http://blog.udacity.com/&q;},{&q;text&q;:&q;My Classroom&q;,&q;href&q;:&q;https://classroom.udacity.com/&q;,&q;classes&q;:[&q;blue&q;]}],&q;isNotAuth&q;:[{&q;text&q;:&q;Sign In&q;,&q;href&q;:&q;https://auth.udacity.com/sign-in?next=https://classroom.udacity.com/authenticated&q;,&q;classes&q;:[&q;blue&q;]},{&q;text&q;:&q;Get Started&q;,&q;href&q;:&q;https://auth.udacity.com/sign-up?next=https://classroom.udacity.com/authenticated&q;,&q;classes&q;:[&q;turquoise&q;]}]},&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavAuthLinks&a;locale=en-US&q;:{&q;isAuth&q;:[{&q;text&q;:&q;Blog&q;,&q;href&q;:&q;http://blog.udacity.com/&q;},{&q;text&q;:&q;My Classroom&q;,&q;href&q;:&q;https://classroom.udacity.com/&q;,&q;classes&q;:[&q;button--primary&q;]}],&q;isNotAuth&q;:[{&q;text&q;:&q;Sign In&q;,&q;href&q;:&q;https://auth.udacity.com/sign-in?next=https://classroom.udacity.com/authenticated&q;},{&q;text&q;:&q;Get Started&q;,&q;href&q;:&q;https://auth.udacity.com/sign-up?next=https://classroom.udacity.com/authenticated&q;,&q;classes&q;:[&q;button--primary&q;]}]},&q;/courses/all?experiment=%7B%22CATALOG_30_EXPERIMENT%22:%7B%22name%22:%22CATALOG_30_EXPERIMENT_V1_VARIANT_1%22,%22variant%22:%22VARIANT_1%22,%22active%22:true,%22props%22:%7B%7D,%22analytics%22:%7B%22variant_id%22:%221%22,%22experiment_id%22:%22cMqPkxoEQOaRL_twxbPBRA%22,%22media_query%22:%22%22,%22disableEarlyAnalytics%22:false%7D%7D%7D@CACHE_LOCALIZED_DATA-skillFilters&a;locale=en-US&q;:[{&q;section&q;:&q;Skills&q;,&q;values&q;:[{&q;title&q;:&q;AI Algorithms&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;AI Algorithms&q;}},{&q;title&q;:&q;AR development&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;AR development&q;}},{&q;title&q;:&q;ARKit&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;ARKit&q;}},{&q;title&q;:&q;Alteryx&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Alteryx&q;}},{&q;title&q;:&q;Android Development&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Android Development&q;}},{&q;title&q;:&q;Blueprint programming&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Blueprint programming&q;}},{&q;title&q;:&q;C++&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;C++&q;}},{&q;title&q;:&q;Career Advancement&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Career Advancement&q;}},{&q;title&q;:&q;CSS&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;CSS&q;}},{&q;title&q;:&q;Controls and Estimation&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Controls and Estimation&q;}},{&q;title&q;:&q;Core Data&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;m ...

# %%
import re

# Remove HTML tags using RegEx
pattern = re.compile(r'<.*?>')  # tags look like <...>
print(pattern.sub('', r.text))  # replace them with blank
# Out:
#
#   window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&&(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof b&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(18)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o=t(18)(r);n.exports=r,o.inPlace(window.history,["pushState","replaceState"],"-")},{}],7:[function(t,n,e){var r=t("ee").get("raf"),o=t(18)(r),i="equestAnimationFrame";n.exports=r,o.inPlace(window,["r"+i,"mozR"+i,"webkitR"+i,"msR"+i],"raf-"),r.on("raf-start",function(t){t[0]=o(t[0],"fn-")})},{}],8:[function(t,n,e){function r(t,n,e){t[0]=a(t[0],"fn-",null,e)}function o(t,n,e){this.method=e,this.timerDuration=isNaN(t[1])?0:+t[1],t[0]=a(t[0],"fn-",this,e)}var i=t("ee").get("timer"),a=t(18)(i),s="setTimeout",c="setInterval",f="clearTimeout",u="-start",d="-";n.exports=i,a.inPlace(window,[s,"setImmediate"],s+d),a.inPlace(window,[c],c+d),a.inPlace(window,[f,"clearImmediate"],f+d),i.on(c+u,r),i.on(s+u,o)},{}],9:[function(t,n,e){function r(t,n){d.inPlace(n,["onreadystatechange"],"fn-",s)}function o(){var t=this,n=u.context(t);t.readyState>3&&!n.resolved&&(n.resolved=!0,u.emit("xhr-resolved",[],t)),d.inPlace(t,y,"fn-",s)}function i(t){g.push(t),h&&(x?x.then(a):w?w(a):(E=-E,O.data=E))}function a(){for(var t=0;t34||p<10)||window.opera||t.addEventListener("progress",function(t){n.lastSize=t.loaded},!1)}),f.on("open-xhr-start",function(t){this.params={method:t[0]},i(this,t[1]),this.metrics={}}),f.on("open-xhr-end",function(t,n){"loader_config"in NREUM&&"xpid"in NREUM.loader_config&&this.sameOrigin&&n.setRequestHeader("X-NewRelic-ID",NREUM.loader_config.xpid)}),f.on("send-xhr-start",function(t,n){var e=this.metrics, ...
# ;NREUM.info={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",licenseKey:"2059d2614a",applicationID:"215318720",sa:1}
#
#
#
#
#   window.DISABLE_EARLY_ANALYTICS = false;if (typeof Object.assign == 'function') {window.ACTIVE_EXPERIMENTS = window.ACTIVE_EXPERIMENTS || {};Object.assign(window.ACTIVE_EXPERIMENTS, {"CATALOG_30_EXPERIMENT":{"name":"CATALOG_30_EXPERIMENT_V1_VARIANT_1","variant":"VARIANT_1","active":true,"props":{},"analytics":{"variant_id":"1","experiment_id":"cMqPkxoEQOaRL_twxbPBRA","media_query":"","disableEarlyAnalytics":false}}});} else {window.ACTIVE_EXPERIMENTS = {"CATALOG_30_EXPERIMENT":{"name":"CATALOG_30_EXPERIMENT_V1_VARIANT_1","variant":"VARIANT_1","active":true,"props":{},"analytics":{"variant_id":"1","experiment_id":"cMqPkxoEQOaRL_twxbPBRA","media_query":"","disableEarlyAnalytics":false}}};}
# html[_ngcontent-sc0] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc0], *[_ngcontent-sc0]::after, *[_ngcontent-sc0]::before {
#   box-sizing: inherit; }
#
# a[_ngcontent-sc0] {
#   color: darkviolet; }
#
# body[_ngcontent-sc0] {
#   color: #028bb1; }
#
# [_nghost-sc0] {
#   display: block;
#   position: relative; }
#
# span.snackbar__content[_ngcontent-sc0] {
#   margin: 0;
#   color: white; }
#
# span.snackbar__content[_ngcontent-sc0]   a[_ngcontent-sc0] {
#     margin: 0;
#     color: white;
#     text-decoration: underline; }
#
# ir-header[_ngcontent-sc0], ir-new-header[_ngcontent-sc0] {
#   position: relative;
#   z-index: 7000; }
#
# .sticky.isFixed[_nghost-sc0]   ir-header[_ngcontent-sc0], .sticky.isFixed   [_nghost-sc0]   ir-header[_ngcontent-sc0], .sticky.isFixed[_nghost-sc0]   ir-new-header[_ngcontent-sc0], .sticky.isFixed   [_nghost-sc0]   ir-new-header[_ngcontent-sc0] {
#   top: auto; }
#
# @media screen and (min-width: 48rem) {
#     .sticky.isFixed[_nghost-sc0]   ir-header[_ngcontent-sc0], .sticky.isFixed   [_nghost-sc0]   ir-header[_ngcontent-sc0], .sticky.isFixed[_nghost-sc0]   ir-new-header[_ngcontent-sc0], .sticky.isFixed   [_nghost-sc0]   ir-new-header[_ngcontent-sc0] {
#       top: 52px; } }html[_ngcontent-sc1] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc1], *[_ngcontent-sc1]::after, *[_ngcontent-sc1]::before {
#   box-sizing: inherit; }
#
# .invisible[_ngcontent-sc1] {
#   visibility: hidden !important; }
#
# .hide[_ngcontent-sc1] {
#   display: none !important; }
#
# .show[_ngcontent-sc1] {
#   display: block !important; }
#
# .sr-only[_ngcontent-sc1] {
#   height: 1px;
#   width: 1px;
#   overflow: hidden;
#   position: absolute !important;
#   clip: rect(1px, 1px, 1px, 1px); }
#
# .hidden-xs-up[_ngcontent-sc1] {
#   display: none !important; }
#
# @media (max-width: 479px) {
#   .hidden-xs-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 480px) {
#   .hidden-sm-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (max-width: 767px) {
#   .hidden-sm-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 768px) {
#   .hidden-md-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (max-width: 991px) {
#   .hidden-md-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 992px) {
#   .hidden-lg-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (max-width: 1179px) {
#   .hidden-lg-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 1180px) {
#   .hidden-xl-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# .hidden-xl-down[_ngcontent-sc1] {
#   display: none !important; }
#
# .visible-print-block[_ngcontent-sc1] {
#   display: none !important; }
#
# @media print {
#     .visible-print-block[_ngcontent-sc1] {
#       display: block !important; } }
#
# .visible-print-inline[_ngcontent-sc1] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline[_ngcontent-sc1] {
#       display: inline !important; } }
#
# .visible-print-inline-block[_ngcontent-sc1] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline-block[_ngcontent-sc1] {
#       display: inline-block !important; } }
#
# @media print {
#   .hidden-print[_ngcontent-sc1] {
#     display: none !important; } }
#
# #contain-all[_ngcontent-sc1] {
#   width: 100%;
#   overflow: hidden;
#   background: #fff;
#   -webkit-backface-visibility: hidden;
#           backface-visibility: hidden;
#   -webkit-transform-style: preserve-3d; }
#
# .outer_contain[_ngcontent-sc1] {
#   margin: 0 auto;
#   max-width: 90rem; }
#
# .contain[_ngcontent-sc1] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto;
#   padding-top: 3rem;
#   padding-bottom: 3rem;
#   padding-left: 1.5rem;
#   padding-right: 1.5rem; }
#
# .contain[_ngcontent-sc1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# @media screen and (min-width: 48rem) {
#
#     .contain[_ngcontent-sc1] {
#       padding-top: 6rem;
#       padding-bottom: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#
#     .contain[_ngcontent-sc1] {
#       padding-left: 0;
#       padding-right: 0; } }
#
# .contain.no-padding[_ngcontent-sc1] {
#     padding: 0; }
#
# .contain.no-padding-top[_ngcontent-sc1] {
#     padding-top: 0; }
#
# .contain.no-padding-bottom[_ngcontent-sc1] {
#     padding-bottom: 0; }
#
# .contain--none[_ngcontent-sc1] {
#     padding-top: 0rem;
#     padding-bottom: 0rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--none[_ngcontent-sc1] {
#         padding-top: 0rem;
#         padding-bottom: 0rem; } }
#
# .contain--small[_ngcontent-sc1] {
#     padding-top: 3rem;
#     padding-bottom: 3rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--small[_ngcontent-sc1] {
#         padding-top: 4.5rem;
#         padding-bottom: 4.5rem; } }
#
# .cards_contain[_ngcontent-sc1] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto; }
#
# .cards_contain[_ngcontent-sc1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# [_ngcontent-sc1]:-webkit-full-screen-ancestor {
#   -webkit-animation: none !important;
#           animation: none !important;
#   -webkit-animation-fill-mode: none !important;
#   animation-fill-mode: none !important; }
#
# [_ngcontent-sc1]:target:before {
#   content: '';
#   display: inline-block;
#   height: 130px;
#   margin: -130px 0 0; }
#
# .header[_ngcontent-sc1] {
#   max-width: 100%;
#   margin-left: auto;
#   margin-right: auto; }
#
# .header[_ngcontent-sc1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# .header.header--clone[_ngcontent-sc1] {
#     width: 100%;
#     top: -1000px; }
#
# .header.header--clone[_ngcontent-sc1]   .header__navbar[_ngcontent-sc1] {
#       height: 4.5rem; }
#
# .header.header--stick[_ngcontent-sc1] {
#     top: 0;
#     background-color: #fff;
#     z-index: 8000;
#     box-shadow: 0px 1px 2px rgba(0, 0, 0, 0.1); }
#
# .header__navbar[_ngcontent-sc1] {
#     max-width: 73.75rem;
#     margin-left: auto;
#     margin-right: auto;
#     height: 4.5rem;
#     padding: 0 1.5em; }
#
# .header__navbar[_ngcontent-sc1]::after {
#       clear: both;
#       content: "";
#       display: table; }
#
# @media screen and (min-width: 48rem) {
#       .header__navbar[_ngcontent-sc1] {
#         height: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#       .header__navbar[_ngcontent-sc1] {
#         padding: 0; } }
#
# .header__navbar--toggle[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 15.25423729%; }
#
# .header__navbar--toggle[_ngcontent-sc1]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--toggle[_ngcontent-sc1] {
#           display: none; } }
#
# .header__navbar--logo[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 66.10169492%; }
#
# .header__navbar--logo[_ngcontent-sc1]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc1] {
#           float: left;
#           display: block;
#           margin-right: 0.84033613%;
#           width: 20.16806723%; }
#           .header__navbar--logo[_ngcontent-sc1]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--catalog[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--catalog[_ngcontent-sc1] {
#           float: left;
#           display: block;
#           margin-right: 0.84033613%;
#           width: 7.56302521%; }
#           .header__navbar--catalog[_ngcontent-sc1]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--navigation[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--navigation[_ngcontent-sc1] {
#           float: left;
#           display: block;
#           margin-right: 1.69491525%;
#           width: 74.57627119%; }
#           .header__navbar--navigation[_ngcontent-sc1]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--logo[_ngcontent-sc1] {
#     text-align: center; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--logo[_ngcontent-sc1] {
#         text-align: left; } }
#
# .header__navbar--logo[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#       width: 11.25rem;
#       height: 1.875rem;
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#           display: block; } }
#
# .header__navbar--logo[_ngcontent-sc1]   .logo-mark[_ngcontent-sc1] {
#       display: block;
#       margin: 0 auto;
#       width: 1.875rem;
#       height: 1.875rem; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc1]   .logo-mark[_ngcontent-sc1] {
#           display: none; } }
#
# .header__navbar--toggle[_ngcontent-sc1]   .nav-toggle[_ngcontent-sc1] {
#     display: block;
#     width: 1.25rem;
#     height: 1.25rem;
#     cursor: pointer;
#     transition: -webkit-transform .25s ease;
#     transition: transform .25s ease;
#     transition: transform .25s ease, -webkit-transform .25s ease; }
#
# .header__navbar--toggle[_ngcontent-sc1]   .nav-toggle[_ngcontent-sc1]   .bar[_ngcontent-sc1] {
#       display: block;
#       width: 100%;
#       height: 0.1875rem;
#       margin-left: -0.5rem;
#       margin-top: 0.1875rem;
#       background: #02b3e4;
#       transition: opacity .25s ease, -webkit-transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease, -webkit-transform .25s ease;
#       -webkit-user-select: none;
#          -moz-user-select: none;
#           -ms-user-select: none;
#               user-select: none; }
#
# .header__navbar--navigation[_ngcontent-sc1]   nav[_ngcontent-sc1] {
#     float: right; }
#
# .header__navbar--navigation[_ngcontent-sc1]   a[_ngcontent-sc1], .header__navbar--navigation[_ngcontent-sc1]   div[_ngcontent-sc1] {
#     float: left; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button[_ngcontent-sc1] {
#     display: none;
#     letter-spacing: 0;
#     font-size: 0.875rem;
#     text-transform: capitalize;
#     height: 2.25rem;
#     font-weight: 400;
#     margin-left: 2.5rem;
#     line-height: 1.9375rem; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button[_ngcontent-sc1]:first-child {
#       margin-left: 0; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--navigation[_ngcontent-sc1]   .button[_ngcontent-sc1] {
#         display: block; } }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--navigation[_ngcontent-sc1] {
#       padding: 0;
#       color: #525c65; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--navigation[_ngcontent-sc1]:hover {
#         color: #474f57; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--primary[_ngcontent-sc1], .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1] {
#       width: 7.75rem;
#       box-shadow: 8px 10px 20px 0px rgba(46, 61, 73, 0.15);
#       background-color: #02b3e4; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--primary[_ngcontent-sc1]:hover, .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1]:hover {
#         box-shadow: 2px 4px 8px 0px rgba(46, 61, 73, 0.2);
#         background-color: #02b7e9; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1] {
#       background-color: #02ccba; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1]:hover {
#         background-color: #02d1bf; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--guest[_ngcontent-sc1], .header__navbar--navigation[_ngcontent-sc1]   .button--student[_ngcontent-sc1] {
#       display: none; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .divider[_ngcontent-sc1] {
#     cursor: default; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .divider[_ngcontent-sc1]::before {
#       content: '';
#       border-left: 1px solid rgba(82, 92, 101, 0.4);
#       width: 0px;
#       height: 12px; }
#
# .header__sidenav[_ngcontent-sc1] {
#     background-color: #2e3d49; }
#
# .header__sidenav--logo[_ngcontent-sc1] {
#       height: 4.5rem;
#       display: block;
#       background-color: #1C262F; }
#
# .header__sidenav--logo[_ngcontent-sc1]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--logo[_ngcontent-sc1]   .logo-link[_ngcontent-sc1] {
#         display: block;
#         width: 100%;
#         height: 100%; }
#
# .header__sidenav--logo[_ngcontent-sc1]   .logo-link[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#           position: relative;
#           top: 50%;
#           -webkit-transform: translateY(-50%);
#           transform: translateY(-50%);
#           padding-left: 1.5em;
#           width: 11.25rem;
#           height: 1.875rem; }
#
# .header__sidenav--logo[_ngcontent-sc1]   .logo-link[_ngcontent-sc1]   #wordmark[_ngcontent-sc1] {
#           fill: #fff; }
#
# .header__sidenav--navigation[_ngcontent-sc1] {
#       display: block; }
#
# .header__sidenav--navigation[_ngcontent-sc1]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   li[_ngcontent-sc1] {
#         height: 4.5rem; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   a[_ngcontent-sc1] {
#         padding-top: 1.5rem;
#         padding-bottom: 1.5rem;
#         color: #fff;
#         display: block;
#         padding-left: 1.5em; }
#
# @media screen and (min-width: 48rem) {
#           .header__sidenav--navigation[_ngcontent-sc1]   a[_ngcontent-sc1] {
#             padding-top: 1.5rem;
#             padding-bottom: 1.5rem; } }
#
# .header__sidenav--navigation[_ngcontent-sc1]   a[_ngcontent-sc1]:hover {
#           color: #cccccc; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   .guest[_ngcontent-sc1], .header__sidenav--navigation[_ngcontent-sc1]   .student[_ngcontent-sc1] {
#         display: none; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   .guest[_ngcontent-sc1]   a[_ngcontent-sc1], .header__sidenav--navigation[_ngcontent-sc1]   .student[_ngcontent-sc1]   a[_ngcontent-sc1] {
#           color: #02b3e4; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   .guest[_ngcontent-sc1]   a[_ngcontent-sc1]:hover, .header__sidenav--navigation[_ngcontent-sc1]   .student[_ngcontent-sc1]   a[_ngcontent-sc1]:hover {
#             color: #01647f; }
#
# [_nghost-sc1] {
#   background: #2e3d49;
#   position: fixed;
#   top: 0;
#   left: 0;
#   height: 100vh;
#   display: block;
#   overflow-y: auto;
#   z-index: -1000;
#   width: 16.25rem;
#   -webkit-overflow-scrolling: touch;
#   display: block; }
#
# @media screen and (min-width: 62rem) {
#     [_nghost-sc1] {
#       display: none; } }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1] {
#     height: 4.5rem;
#     display: block;
#     background-color: #1C262F; }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1]::after {
#       clear: both;
#       content: "";
#       display: table; }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       padding-left: 1.5em;
#       width: 11.25rem;
#       height: 1.875rem; }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1]   #wordmark[_ngcontent-sc1] {
#       fill: #fff; }
#
# [_nghost-sc1]   ul[_ngcontent-sc1] {
#     list-style: none;
#     padding: 0; }
#
# .page-lg[_nghost-sc1], .page-lg   [_nghost-sc1] {
#   display: none; }html[_ngcontent-sc2] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc2], *[_ngcontent-sc2]::after, *[_ngcontent-sc2]::before {
#   box-sizing: inherit; }
#
# [_nghost-sc2] {
#   position: absolute;
#   width: 100%;
#   top: 0;
#   left: 0;
#   min-height: 100vh;
#   z-index: 0;
#   transition: -webkit-transform 0.3s ease;
#   transition: transform 0.3s ease;
#   transition: transform 0.3s ease, -webkit-transform 0.3s ease;
#   background: #fff; }
#
# .menu--open[_nghost-sc2]:not(.nav-experiment), .menu--open:not(.nav-experiment)   [_nghost-sc2] {
#   -webkit-transform: translateX(16.25rem);
#           transform: translateX(16.25rem); }
#
# .menu--open[_nghost-sc2], .menu--open   [_nghost-sc2] {
#   height: 100vh;
#   overflow: hidden; }
#
# @media screen and (min-width: 62rem) {
#     .menu--open[_nghost-sc2], .menu--open   [_nghost-sc2] {
#       overflow: auto;
#       -webkit-transform: none;
#               transform: none;
#       height: auto; } }
#
# .sticky[_nghost-sc2]:not(.no-sticky-header), .sticky:not(.no-sticky-header)   [_nghost-sc2] {
#   padding-top: 4.5rem; }
#
# @media screen and (min-width: 48rem) {
#     .sticky[_nghost-sc2]:not(.no-sticky-header), .sticky:not(.no-sticky-header)   [_nghost-sc2] {
#       padding-top: 6rem; } }
#
# .page-cn.page-school-of-data-science[_nghost-sc2], .page-cn.page-school-of-data-science   [_nghost-sc2] {
#   padding-top: 0; }
#
# .page-riseup[_nghost-sc2], .page-riseup   [_nghost-sc2] {
#   background: #2e3d49; }html[_ngcontent-sc3] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc3], *[_ngcontent-sc3]::after, *[_ngcontent-sc3]::before {
#   box-sizing: inherit; }
#
# [_nghost-sc3] {
#   display: block;
#   overflow: hidden; }
#
# .moustache[_ngcontent-sc3] {
#   position: relative;
#   width: 100%;
#   background: #fff;
#   padding: 0.75rem 2.5rem 0.75rem 1.5rem;
#   color: #fff;
#   text-align: center;
#   z-index: 8999; }
#
# .moustache[_ngcontent-sc3]   p[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     border-bottom: none; }
#
# .moustache[_ngcontent-sc3]   p[_ngcontent-sc3]   a.moustache__link--button[_ngcontent-sc3] {
#       border-bottom: 1px solid;
#       margin: 0 0.8rem; }
#
# .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #02b3e4;
#     display: inline-block;
#     margin: 0; }
#
# .moustache[_ngcontent-sc3]   .close-btn[_ngcontent-sc3] {
#     position: absolute;
#     top: 0;
#     right: 1rem;
#     bottom: 0;
#     display: flex;
#     background-color: transparent;
#     border: none;
#     outline: none;
#     opacity: 0.75;
#     margin: auto 0;
#     padding: 0;
#     color: #fff;
#     transition: opacity 0.3s ease; }
#
# .moustache[_ngcontent-sc3]   .close-btn[_ngcontent-sc3]   svg[_ngcontent-sc3] {
#       height: 0.8rem;
#       width: auto; }
#
# .moustache[_ngcontent-sc3]   .close-btn[_ngcontent-sc3]:hover {
#       opacity: 1; }
#
# .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #02b3e4; }
#
# .moustache.white[_ngcontent-sc3] {
#     background: #fff; }
#
# .moustache.white[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.white[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #02b3e4;
#       font-size: 1rem; }
#
# .moustache.white[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #02b3e4; }
#
# .moustache.blue[_ngcontent-sc3] {
#     background: #02b3e4; }
#
# .moustache.blue[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.blue[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.blue[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.blue-turquoise[_ngcontent-sc3] {
#     background: linear-gradient(to right, #02b3e4, #02ccba); }
#
# .moustache.blue-turquoise[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.blue-turquoise[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.blue-turquoise[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.purple-turquoise[_ngcontent-sc3] {
#     background: linear-gradient(to right, #a951ed, #02ccba); }
#
# .moustache.purple-turquoise[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.purple-turquoise[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.purple-turquoise[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.magenta-yellow[_ngcontent-sc3] {
#     background: linear-gradient(to right, #ff5483, #ffae0c); }
#
# .moustache.magenta-yellow[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.magenta-yellow[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.magenta-yellow[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.yellow-purple[_ngcontent-sc3] {
#     background: linear-gradient(to right, #ffae0c, #a951ed); }
#
# .moustache.yellow-purple[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.yellow-purple[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.yellow-purple[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.yellow-on-black[_ngcontent-sc3] {
#     background: #000; }
#
# .moustache.yellow-on-black[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.yellow-on-black[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #ffae0c;
#       font-size: 1rem; }
#
# .moustache.yellow-on-black[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #ffae0c; }
#
# .page-in.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-corporate[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-corporate   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-campaign[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-campaign   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-google-india-scholarships[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-google-india-scholarships   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-ucollege[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-ucollege   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   display: none; }
#
# .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   background: #02b3e4; }
#
# .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #fff;
#     font-size: 1rem; }
#
# .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #fff; }
#
# .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   background: #fff; }
#
# .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #02b3e4;
#     font-size: 1rem; }
#
# .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #02b3e4; }
#
# .page-cn.page-homepage.sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   background: #02b3e4; }
#
# .page-cn.page-homepage.sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #fff;
#     font-size: 1rem; }
#
# .page-cn.page-homepage.sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #fff; }
#
# .sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3], .sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   position: fixed;
#   z-index: 8001;
#   top: 0; }
#
# .page-cn.page-20181111[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn.page-20181111   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   display: none; }html[_ngcontent-sc4] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc4], *[_ngcontent-sc4]::after, *[_ngcontent-sc4]::before {
#   box-sizing: inherit; }
#
# .invisible[_ngcontent-sc4] {
#   visibility: hidden !important; }
#
# .hide[_ngcontent-sc4] {
#   display: none !important; }
#
# .show[_ngcontent-sc4] {
#   display: block !important; }
#
# .sr-only[_ngcontent-sc4] {
#   height: 1px;
#   width: 1px;
#   overflow: hidden;
#   position: absolute !important;
#   clip: rect(1px, 1px, 1px, 1px); }
#
# .hidden-xs-up[_ngcontent-sc4] {
#   display: none !important; }
#
# @media (max-width: 479px) {
#   .hidden-xs-down[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (min-width: 480px) {
#   .hidden-sm-up[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (max-width: 767px) {
#   .hidden-sm-down[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (min-width: 768px) {
#   .hidden-md-up[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (max-width: 991px) {
#   .hidden-md-down[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (min-width: 992px) {
#   .hidden-lg-up[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (max-width: 1179px) {
#   .hidden-lg-down[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (min-width: 1180px) {
#   .hidden-xl-up[_ngcontent-sc4] {
#     display: none !important; } }
#
# .hidden-xl-down[_ngcontent-sc4] {
#   display: none !important; }
#
# .visible-print-block[_ngcontent-sc4] {
#   display: none !important; }
#
# @media print {
#     .visible-print-block[_ngcontent-sc4] {
#       display: block !important; } }
#
# .visible-print-inline[_ngcontent-sc4] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline[_ngcontent-sc4] {
#       display: inline !important; } }
#
# .visible-print-inline-block[_ngcontent-sc4] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline-block[_ngcontent-sc4] {
#       display: inline-block !important; } }
#
# @media print {
#   .hidden-print[_ngcontent-sc4] {
#     display: none !important; } }
#
# #contain-all[_ngcontent-sc4] {
#   width: 100%;
#   overflow: hidden;
#   background: #fff;
#   -webkit-backface-visibility: hidden;
#           backface-visibility: hidden;
#   -webkit-transform-style: preserve-3d; }
#
# .outer_contain[_ngcontent-sc4] {
#   margin: 0 auto;
#   max-width: 90rem; }
#
# .contain[_ngcontent-sc4] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto;
#   padding-top: 3rem;
#   padding-bottom: 3rem;
#   padding-left: 1.5rem;
#   padding-right: 1.5rem; }
#
# .contain[_ngcontent-sc4]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# @media screen and (min-width: 48rem) {
#
#     .contain[_ngcontent-sc4] {
#       padding-top: 6rem;
#       padding-bottom: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#
#     .contain[_ngcontent-sc4] {
#       padding-left: 0;
#       padding-right: 0; } }
#
# .contain.no-padding[_ngcontent-sc4] {
#     padding: 0; }
#
# .contain.no-padding-top[_ngcontent-sc4] {
#     padding-top: 0; }
#
# .contain.no-padding-bottom[_ngcontent-sc4] {
#     padding-bottom: 0; }
#
# .contain--none[_ngcontent-sc4] {
#     padding-top: 0rem;
#     padding-bottom: 0rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--none[_ngcontent-sc4] {
#         padding-top: 0rem;
#         padding-bottom: 0rem; } }
#
# .contain--small[_ngcontent-sc4] {
#     padding-top: 3rem;
#     padding-bottom: 3rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--small[_ngcontent-sc4] {
#         padding-top: 4.5rem;
#         padding-bottom: 4.5rem; } }
#
# .cards_contain[_ngcontent-sc4] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto; }
#
# .cards_contain[_ngcontent-sc4]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# [_ngcontent-sc4]:-webkit-full-screen-ancestor {
#   -webkit-animation: none !important;
#           animation: none !important;
#   -webkit-animation-fill-mode: none !important;
#   animation-fill-mode: none !important; }
#
# [_ngcontent-sc4]:target:before {
#   content: '';
#   display: inline-block;
#   height: 130px;
#   margin: -130px 0 0; }
#
# .header[_ngcontent-sc4], [_nghost-sc4] {
#   max-width: 100%;
#   margin-left: auto;
#   margin-right: auto; }
#
# .header[_ngcontent-sc4]::after, [_nghost-sc4]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# .header.header--clone[_ngcontent-sc4], .header--clone[_nghost-sc4] {
#     width: 100%;
#     top: -1000px; }
#
# .header.header--clone[_ngcontent-sc4]   .header__navbar[_ngcontent-sc4], .header--clone[_nghost-sc4]   .header__navbar[_ngcontent-sc4], .header.header--clone[_ngcontent-sc4]   header[_ngcontent-sc4], .header--clone[_nghost-sc4]   header[_ngcontent-sc4] {
#       height: 4.5rem; }
#
# .header.header--stick[_ngcontent-sc4], .header--stick[_nghost-sc4] {
#     top: 0;
#     background-color: #fff;
#     z-index: 8000;
#     box-shadow: 0px 1px 2px rgba(0, 0, 0, 0.1); }
#
# .header__navbar[_ngcontent-sc4], header[_ngcontent-sc4] {
#     max-width: 73.75rem;
#     margin-left: auto;
#     margin-right: auto;
#     height: 4.5rem;
#     padding: 0 1.5em; }
#
# .header__navbar[_ngcontent-sc4]::after, header[_ngcontent-sc4]::after {
#       clear: both;
#       content: "";
#       display: table; }
#
# @media screen and (min-width: 48rem) {
#       .header__navbar[_ngcontent-sc4], header[_ngcontent-sc4] {
#         height: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#       .header__navbar[_ngcontent-sc4], header[_ngcontent-sc4] {
#         padding: 0; } }
#
# .header__navbar--toggle[_ngcontent-sc4] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 15.25423729%; }
#
# .header__navbar--toggle[_ngcontent-sc4]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--toggle[_ngcontent-sc4] {
#           display: none; } }
#
# .header__navbar--logo[_ngcontent-sc4] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 66.10169492%; }
#
# .header__navbar--logo[_ngcontent-sc4]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc4] {
#           float: left;
#           display: block;
#           margin-right: 0.84033613%;
#           width: 20.16806723%; }
#           .header__navbar--logo[_ngcontent-sc4]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--catalog[_ngcontent-sc4] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--catalog[_ngcontent-sc4] {
#           float: left;
#           display: block;
#           margin-right: 0.84033613%;
#           width: 7.56302521%; }
#           .header__navbar--catalog[_ngcontent-sc4]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--navigation[_ngcontent-sc4] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--navigation[_ngcontent-sc4] {
#           float: left;
#           display: block;
#           margin-right: 1.69491525%;
#           width: 74.57627119%; }
#           .header__navbar--navigation[_ngcontent-sc4]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--logo[_ngcontent-sc4] {
#     text-align: center; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--logo[_ngcontent-sc4] {
#         text-align: left; } }
#
# .header__navbar--logo[_ngcontent-sc4]   .logo-wordmark[_ngcontent-sc4], .header__navbar--logo[_ngcontent-sc4]   .logo-wordmark--cn[_ngcontent-sc4] {
#       width: 11.25rem;
#       height: 1.875rem;
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc4]   .logo-wordmark[_ngcontent-sc4], .header__navbar--logo[_ngcontent-sc4]   .logo-wordmark--cn[_ngcontent-sc4] {
#           display: block; } }
#
# .header__navbar--logo[_ngcontent-sc4]   .logo-mark[_ngcontent-sc4] {
#       display: block;
#       margin: 0 auto;
#       width: 1.875rem;
#       height: 1.875rem; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc4]   .logo-mark[_ngcontent-sc4] {
#           display: none; } }
#
# .header__navbar--toggle[_ngcontent-sc4]   .nav-toggle[_ngcontent-sc4] {
#     display: block;
#     width: 1.25rem;
#     height: 1.25rem;
#     cursor: pointer;
#     transition: -webkit-transform .25s ease;
#     transition: transform .25s ease;
#     transition: transform .25s ease, -webkit-transform .25s ease; }
#
# .header__navbar--toggle[_ngcontent-sc4]   .nav-toggle[_ngcontent-sc4]   .bar[_ngcontent-sc4] {
#       display: block;
#       width: 100%;
#       height: 0.1875rem;
#       margin-left: -0.5rem;
#       margin-top: 0.1875rem;
#       background: #02b3e4;
#       transition: opacity .25s ease, -webkit-transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease, -webkit-transform .25s ease;
#       -webkit-user-select: none;
#          -moz-user-select: none;
#           -ms-user-select: none;
#               user-select: none; }
#
# .header__navbar--navigation[_ngcontent-sc4]   nav[_ngcontent-sc4] {
#     float: right; }
#
# .header__navbar--navigation[_ngcontent-sc4]   a[_ngcontent-sc4], .header__navbar--navigation[_ngcontent-sc4]   div[_ngcontent-sc4] {
#     float: left; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button[_ngcontent-sc4] {
#     display: none;
#     letter-spacing: 0;
#     font-size: 0.875rem;
#     text-transform: capitalize;
#     height: 2.25rem;
#     font-weight: 400;
#     margin-left: 2.5rem;
#     line-height: 1.9375rem; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button[_ngcontent-sc4]:first-child {
#       margin-left: 0; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--navigation[_ngcontent-sc4]   .button[_ngcontent-sc4] {
#         display: block; } }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--navigation[_ngcontent-sc4] {
#       padding: 0;
#       color: #525c65; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--navigation[_ngcontent-sc4]:hover {
#         color: #474f57; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--primary[_ngcontent-sc4], .header__navbar--navigation[_ngcontent-sc4]   .button--turquoise[_ngcontent-sc4] {
#       width: 7.75rem;
#       box-shadow: 8px 10px 20px 0px rgba(46, 61, 73, 0.15);
#       background-color: #02b3e4; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--primary[_ngcontent-sc4]:hover, .header__navbar--navigation[_ngcontent-sc4]   .button--turquoise[_ngcontent-sc4]:hover {
#         box-shadow: 2px 4px 8px 0px rgba(46, 61, 73, 0.2);
#         background-color: #02b7e9; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--turquoise[_ngcontent-sc4] {
#       background-color: #02ccba; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--turquoise[_ngcontent-sc4]:hover {
#         background-color: #02d1bf; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--guest[_ngcontent-sc4], .header__navbar--navigation[_ngcontent-sc4]   .button--student[_ngcontent-sc4] {
#       display: none; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .divider[_ngcontent-sc4] {
#     cursor: default; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .divider[_ngcontent-sc4]::before {
#       content: '';
#       border-left: 1px solid rgba(82, 92, 101, 0.4);
#       width: 0px;
#       height: 12px; }
#
# .header__sidenav[_ngcontent-sc4] {
#     background-color: #2e3d49; }
#
# .header__sidenav--logo[_ngcontent-sc4] {
#       height: 4.5rem;
#       display: block;
#       background-color: #1C262F; }
#
# .header__sidenav--logo[_ngcontent-sc4]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--logo[_ngcontent-sc4]   .logo-link[_ngcontent-sc4] {
#         display: block;
#         width: 100%;
#         height: 100%; }
#
# .header__sidenav--logo[_ngcontent-sc4]   .logo-link[_ngcontent-sc4]   .logo-wordmark[_ngcontent-sc4], .header__sidenav--logo[_ngcontent-sc4]   .logo-link[_ngcontent-sc4]   .logo-wordmark--cn[_ngcontent-sc4] {
#           position: relative;
#           top: 50%;
#           -webkit-transform: translateY(-50%);
#           transform: translateY(-50%);
#           padding-left: 1.5em;
#           width: 11.25rem;
#           height: 1.875rem; }
#
# .header__sidenav--logo[_ngcontent-sc4]   .logo-link[_ngcontent-sc4]   #wordmark[_ngcontent-sc4] {
#           fill: #fff; }
#
# .header__sidenav--navigation[_ngcontent-sc4] {
#       display: block; }
#
# .header__sidenav--navigation[_ngcontent-sc4]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   li[_ngcontent-sc4] {
#         height: 4.5rem; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   a[_ngcontent-sc4] {
#         padding-top: 1.5rem;
#         padding-bottom: 1.5rem;
#         color: #fff;
#         display: block;
#         padding-left: 1.5em; }
#
# @media screen and (min-width: 48rem) {
#           .header__sidenav--navigation[_ngcontent-sc4]   a[_ngcontent-sc4] {
#             padding-top: 1.5rem;
#             padding-bottom: 1.5rem; } }
#
# .header__sidenav--navigation[_ngcontent-sc4]   a[_ngcontent-sc4]:hover {
#           color: #cccccc; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   .guest[_ngcontent-sc4], .header__sidenav--navigation[_ngcontent-sc4]   .student[_ngcontent-sc4] {
#         display: none; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   .guest[_ngcontent-sc4]   a[_ngcontent-sc4], .header__sidenav--navigation[_ngcontent-sc4]   .student[_ngcontent-sc4]   a[_ngcontent-sc4] {
#           color: #02b3e4; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   .guest[_ngcontent-sc4]   a[_ngcontent-sc4]:hover, .header__sidenav--navigation[_ngcontent-sc4]   .student[_ngcontent-sc4]   a[_ngcontent-sc4]:hover {
#             color: #01647f; }
#
# html[_ngcontent-sc4] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc4], *[_ngcontent-sc4]::after, *[_ngcontent-sc4]::before {
#   box-sizing: inherit; }
#
# [_nghost-sc4] {
#   display: block;
#   z-index: 1;
#   position: relative; }
#
# header[_ngcontent-sc4]   .header__navbar--navigation[_ngcontent-sc4] {
#   float: right; }
#
# @-webkit-keyframes sticky-slide-down {
#   100% {
#     -webkit-transform: translateY(0);
#             transform: translateY(0); } }
#
# @keyframes sticky-slide-down {
#   100% {
#     -webkit-transform: translateY(0);
#             transform: translateY(0); } }
#
# .header-icons[_ngcontent-sc4] {
#   display: block;
#   position: relative;
#   top: 1.4rem;
#   float: right;
#   margin-right: -0.7rem; }
#
# .header-icons[_ngcontent-sc4]   svg[_ngcontent-sc4] {
#     height: 1.8rem;
#     fill: #02b3e4; }
#
# @media screen and (min-width: 30rem) {
#     .header-icons[_ngcontent-sc4] {
#       display: none; } }
#
# .phone-icon[_ngcontent-sc4] {
#   display: none;
#   line-height: 0; }
#
# .show-sales-widget[_nghost-sc4]   .phone-icon[_ngcontent-sc4], .show-sales-widget   [_nghost-sc4]   .phone-icon[_ngcontent-sc4] {
#   display: block;
#   position: relative;
#   top: 1.4rem;
#   float: right;
#   margin-right: -0.7rem;
#   top: 50%;
#   -webkit-transform: translateY(-50%);
#           transform: translateY(-50%); }
#
# .show-sales-widget[_nghost-sc4]   .phone-icon[_ngcontent-sc4]   svg[_ngcontent-sc4], .show-sales-widget   [_nghost-sc4]   .phone-icon[_ngcontent-sc4]   svg[_ngcontent-sc4] {
#     height: 1.8rem;
#     fill: #02b3e4; }
#
# @media screen and (min-width: 30rem) {
#     .show-sales-widget[_nghost-sc4]   .phone-icon[_ngcontent-sc4], .show-sales-widget   [_nghost-sc4]   .phone-icon[_ngcontent-sc4] {
#       display: none; } }
#
# .page-homepage[_nghost-sc4]   .logo-wordmark[_ngcontent-sc4]   h1[_ngcontent-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-homepage   [_nghost-sc4]   .logo-wordmark[_ngcontent-sc4]   h1[_ngcontent-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-homepage[_nghost-sc4]   .logo-wordmark--cn[_ngcontent-sc4]   h1[_ngcontent-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-homepage   [_nghost-sc4]   .logo-wordmark--cn[_ngcontent-sc4]   h1[_ngcontent-sc4]   img.logo-wordmark--img[_ngcontent-sc4] {
#   padding-bottom: 1.5rem;
#   width: 180px; }
#
# .page-homepage[_nghost-sc4]   .logo-wordmark--cn[_ngcontent-sc4]   h1[_ngcontent-sc4], .page-homepage   [_nghost-sc4]   .logo-wordmark--cn[_ngcontent-sc4]   h1[_ngcontent-sc4] {
#   margin-bottom: 0; }
#
# .page-eu.page-homepage[_nghost-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-eu.page-homepage   [_nghost-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-in.page-homepage[_nghost-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-in.page-homepage   [_nghost-sc4]   img.logo-wordmark--img[_ngcontent-sc4] {
#   padding-bottom: 1.5rem; }
#
# .experiment-cro-br-header[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .experiment-cro-br-header   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .experiment-cro-br-header[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .experiment-cro-br-header   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .experiment-cro-br-header[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .experiment-cro-br-header   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .experiment-cro-br-header[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .experiment-cro-br-header   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .experiment-cro-br-header[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .experiment-cro-br-header   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .experiment-cro-br-header[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .experiment-cro-br-header   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .experiment-cro-br-header[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #mark[_ngcontent-sc4], .experiment-cro-br-header   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #mark[_ngcontent-sc4], .experiment-cro-br-header[_nghost-sc4]   header[_ngcontent-sc4]   #mark[_ngcontent-sc4], .experiment-cro-br-header   [_nghost-sc4]   header[_ngcontent-sc4]   #mark[_ngcontent-sc4] {
#   fill: #fff; }
#
# .experiment-cro-br-header[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .experiment-cro-br-header   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .experiment-cro-br-header[_nghost-sc4]   header[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .experiment-cro-br-header   [_nghost-sc4]   header[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4] {
#   stroke: #fff; }
#
# ...
#         position: relative; } }
#
# .card__overlay[_ngcontent-sc343]:hover {
#       display: flex; }
#
# .card__overlay__summary[_ngcontent-sc343] {
#       margin: 0 2rem;
#       flex: 1;
#       display: flex;
#       flex-direction: column;
#       justify-content: flex-start;
#       padding-top: 2rem;
#       line-height: 1.6rem;
#       color: #fff;
#       font-size: 0.75rem; }
#
# .card__overlay__summary[_ngcontent-sc343]   p[_ngcontent-sc343] {
#         margin: 0;
#         padding: 0;
#         line-height: inherit;
#         color: inherit;
#         font-size: inherit; }
#
# .card__overlay[_ngcontent-sc343]   span.card__overlay__enrollBy[_ngcontent-sc343] {
#       letter-spacing: 0;
#       line-height: 2rem;
#       height: 2rem;
#       text-transform: none;
#       font-size: 1rem;
#       font-weight: 600; }
#
# .card__tag[_ngcontent-sc343] {
#     color: #fff;
#     position: absolute;
#     top: 1rem;
#     left: 1rem;
#     line-height: 1em;
#     font-weight: 700;
#     font-size: 0.875rem; }
#
# .card__rating[_ngcontent-sc343] {
#     position: absolute;
#     top: 0;
#     right: 1rem;
#     color: #fff;
#     z-index: 99; }
#
# @media screen and (min-width: 48rem) {
#       .card__rating[_ngcontent-sc343] {
#         display: none;
#         right: 0; } }
#
# .card__stars[_ngcontent-sc343] {
#     display: inline-block;
#     margin: 0 auto;
#     height: 0.75rem;
#     width: 4.78125rem;
#     margin-top: 1rem;
#     margin-right: 0.4rem;
#     position: relative;
#     background-image: url("/assets/iridium/images/course-catalog/stars-white.svg");
#     background-position: 0 0;
#     background-size: 4.78125rem 1.5rem;
#     background-repeat: no-repeat; }
#
# @media screen and (min-width: 48rem) {
#       .card__stars[_ngcontent-sc343] {
#         margin-top: 2.6rem; } }
#
# .card__stars__fill[_ngcontent-sc343] {
#       position: absolute;
#       top: 0;
#       left: 0;
#       height: 100%;
#       background-image: url("/assets/iridium/images/course-catalog/stars-white.svg");
#       background-position: 0 -0.75rem;
#       background-size: 4.78125rem 1.5rem;
#       background-repeat: no-repeat; }
#
# .card__logos[_ngcontent-sc343] {
#     display: flex;
#     justify-content: center;
#     align-items: center;
#     flex-wrap: wrap; }
#
# .card__logos[_ngcontent-sc343]   img[_ngcontent-sc343] {
#       height: 2.9375rem;
#       margin: 0 1.5rem; }
#
# .card__title[_ngcontent-sc343] {
#     color: #2e3d49;
#     line-height: 1.3em;
#     font-size: 1.5rem;
#     font-weight: 800; }
#
# @media screen and (min-width: 48rem) {
#       .card__title[_ngcontent-sc343] {
#         font-size: 1.5rem; } }
#
# .card__collaboration[_ngcontent-sc343] {
#     letter-spacing: 0.09375rem;
#     text-transform: uppercase;
#     line-height: 2em;
#     margin: 2rem 0;
#     font-size: 0.75rem;
#     font-weight: 600; }
#
# .card__collaboration--mobile[_ngcontent-sc343] {
#       display: block;
#       margin: 0; }
#
# .card__collaboration--mobile[_ngcontent-sc343]   .h6[_ngcontent-sc343] {
#         font-weight: 400; }
#
# @media screen and (min-width: 48rem) {
#         .card__collaboration--mobile[_ngcontent-sc343] {
#           display: none; } }
#
# .card__collaboration--mobile[_ngcontent-sc343]    > .card__logos[_ngcontent-sc343] {
#         display: flex;
#         justify-content: flex-start;
#         align-items: center;
#         margin-bottom: 1rem; }
#
# .card__collaboration--mobile[_ngcontent-sc343]    > .card__logos[_ngcontent-sc343]   img[_ngcontent-sc343] {
#           margin: 0 1rem;
#           max-height: 1.8125rem; }
#
# .card__collaboration--mobile[_ngcontent-sc343]    > .card__logos[_ngcontent-sc343]   img[_ngcontent-sc343]:first-of-type {
#             margin-left: 0; }
#
# .card__concepts[_ngcontent-sc343]   h6[_ngcontent-sc343] {
#     font-weight: 400;
#     margin: 0;
#     padding: 0;
#     line-height: 2rem;
#     font-size: 1rem; }
#
# .card__footer[_ngcontent-sc343] {
#     background: #02b3e4;
#     padding: 0 1.25rem;
#     height: 3rem;
#     color: #fff;
#     display: flex;
#     flex-shrink: 0;
#     flex-direction: row;
#     justify-content: space-between;
#     align-items: center;
#     z-index: 1000; }
#
# .card__button[_ngcontent-sc343] {
#     background: none;
#     border: none;
#     height: auto;
#     letter-spacing: 0.045625rem;
#     color: #fff;
#     position: relative;
#     margin-right: 1rem;
#     font-weight: 600;
#     font-size: 0.8125rem; }
#
# .card__button[_ngcontent-sc343]:after {
#       content: '';
#       width: 0.9375rem;
#       height: 100%;
#       display: block;
#       background-image: url(/assets/iridium/images/course-catalog/icon-white-arrow.svg);
#       background-position: center;
#       background-repeat: no-repeat;
#       position: absolute;
#       right: -0.9375rem;
#       top: 0; }
#
#
#
#
#
# -->
# -->
# -->
# -->
# -->
# -->
# -->
# -->
# -->
# -->
# -->
# -->
# -->
# -->
#
#
# Explore SchoolsBack to Menu Artificial Intelligence Back to MenuNanodegree Programs Machine Learning Engineer  AI Programming with Python  Deep Learning  Artificial Intelligence for Trading  Computer Vision  Natural Language Processing  Deep Reinforcement Learning  Artificial Intelligence  Data Science Back to MenuNanodegree Programs Data Analyst  Predictive Analytics for Business  Data Scientist  Business Analytics  Programming for Data Science  Programming and Development Back to MenuNanodegree Programs Introduction to Programming  Front End Web Developer  iOS Developer  Full Stack Web Developer  React  Mobile Web Specialist  Learn Unreal VR Foundations  Blockchain Developer  Cybersecurity  Android Developer  Autonomous Systems Back to MenuNanodegree Programs Self Driving Car Engineer Nanodegree  Intro to Self-Driving Cars  Robotic Software Engineer  Flying Car  Business Back to MenuNanodegree Programs Predictive Analytics for Business  Digital Marketing  Business Analytics  Google Ads  Design Sprint Foundations  Google Analytics CareerFull Catalog Catalog  Paths  Nanodegree  Career Help  For Enterprise  Sign In  Get Started Explore Artificial Intelligence Nanodegree Programs Machine Learning Engineer  AI Programming with Python  Deep Learning  Artificial Intelligence for Trading  Computer Vision  Natural Language Processing  Deep Reinforcement Learning  Artificial Intelligence  Data Science Nanodegree Programs Data Analyst  Predictive Analytics for Business  Data Scientist  Business Analytics  Programming for Data Science  Programming and Development Nanodegree Programs Introduction to Programming  Front End Web Developer  iOS Developer  Full Stack Web Developer  React  Mobile Web Specialist  Learn Unreal VR Foundations  Blockchain Developer  Cybersecurity  Android Developer  Autonomous Systems Nanodegree Programs Self Driving Car Engineer Nanodegree  Intro to Self-Driving Cars  Robotic Software Engineer  Flying Car  Business Nanodegree Programs Predictive Analytics for Business  Digital Marketing  Business Analytics  Google Ads  Design Sprint Foundations  Google Analytics  Career Full Catalog Catalog  Paths  Nanodegree  Career Help  For Enterprise  Sign In  Get Started CatalogAll SchoolsArtificial IntelligenceData ScienceProgrammingAutonomous SystemsBusiness Filters  Back  Clear All  Type  Nanodegree Program
#  Free Courses
#  Clear  Skill Level  Beginner
#  Intermediate
#  Advanced
#  Clear  Duration  &lt;1 month
#  1 - 3 months
#  3+ months
#  Clear  Skills  AI Algorithms
#  AR development
#  ARKit
#  Alteryx
#  Android Development
#  Blueprint programming
#  C++
#  Career Advancement
#  CSS
#  Controls and Estimation
#  Core Data
#  Deep Learning
#  Design Sprint
#  Digital Marketing
#  Display Ads
#  Excel
#  Facebook Marketing
#  Google VR SDK for Unity
#  HTML
#  Java programming
#  JavaScript
#  Jupyter Notebooks
#  Kalman Filters
#  Machine Learning
#  Mobile Web Apps
#  Networking
#  Neural Networks
#  Offline Capable Web Apps
#  Optimization
#  Predictive Modeling
#  Probability
#  Prototyping
#  Python
#  React
#  React Native
#  Redux
#  Robot Operating System
#  Robotics
#  SQL
#  Search Ads
#  Search Algorithms
#  Self-Driving Cars
#  Social Media Marketing
#  Statistics
#  Supervised Learning
#  Swift programming
#  Tableau
#  UIKit
#  Unity
#  Unity ARKit Plugin
#  Unreal
#  Unsupervised Learning
#  User testing
#  VR development
#  Web Tooling and Automation
#  YouTube Marketing
#  Clear  229 results(2148)(2148)Enroll by November 14Udacity's Intro to Programming is your first step towards careers in Web and App Development, Machine Learning, Data Science, AI, and more! This program is perfect for beginners.School of ProgrammingIntroduction to ProgrammingConcepts CoveredIntroduction to Programming, HTML, CSS, Python beginner $599 USDLearn More(0)New!(0)This course is your first step towards a career in programming.School of ProgrammingWhat is Programming? beginner FreeLearn More(1998)(1998)Enroll by November 14Use Python, SQL, and statistics to uncover insights, communicate critical findings, and create data-driven solutions.In Collaboration WithSchool of Data ScienceData AnalystIn Collaboration With intermediate $999 USDLearn More(723)New!(723)Enroll by November 14Master the Swift programming language, and create a portfolio of iOS apps for iPhone and iPad to showcase your skills!In Collaboration WithSchool of ProgrammingiOS DeveloperConcepts CoveredSwift programming, Core Data, UIKit, iOS networking, app publishing, User interfacesIn Collaboration With intermediate $999 USDLearn More(1516)(1516)Enroll by November 28In this program, you’ll prepare for a job as a Full Stack Web Developer, and learn to create complex server-side web applications that use powerful relational databases to persistently store data.In Collaboration WithSchool of ProgrammingFull Stack Web DeveloperConcepts CoveredPython, JavaScript, SQL, HTML5 &amp; CSS3, Python, DatabasesIn Collaboration With intermediate $999 USDLearn More(387)(387)Enroll by November 14Learn to apply predictive analytics and business intelligence to solve real-world business problems.In Collaboration WithSchool of Data SciencePredictive Analytics for BusinessIn Collaboration With intermediate $999 USDLearn More(2353)(2353)Enroll by November 21In this program you will master Supervised, Unsupervised, Reinforcement, and Deep Learning fundamentals. You will also complete a capstone project in your chosen domain.In Collaboration WithSchool of Artificial IntelligenceMachine Learning EngineerConcepts CoveredMachine Learning, Supervised Learning, Unsupervised Learning, Reinforcement Learning, Deep LearningIn Collaboration With advanced $999 USDLearn More(817)New!(817)Enroll by December 6Self-driving cars are set to revolutionize the way we live. This is transformational technology, on the cutting-edge of robotics, machine learning, software engineering, and mechanical engineering. In...In Collaboration WithSchool of Autonomous SystemsSelf Driving Car Engineer NanodegreeConcepts CoveredComputer Vision, Deep Learning, Sensor Fusion, LocalizationIn Collaboration With advanced $1,199 USDLearn More(750)(750)Enroll by November 21Gain real-world experience running live campaigns as you learn from top experts in the field. Launch your career with a 360-degree understanding of digital marketing.In Collaboration WithSchool of BusinessDigital MarketingConcepts CoveredDigital Marketing, Social Media Marketing, Facebook Marketing, Search Engine Optimization, Search Engine MarketingIn Collaboration With beginner $999 USDLearn More(442)(442)Enroll by November 30React is completely transforming Front-End Development. Master this powerful UI library from Facebook with Udacity.School of ProgrammingReactConcepts CoveredReact, Redux, React Native intermediate $999 USDLearn More(317)(317)Enroll by December 5Prepare for Google's Mobile Web Specialist certification with courses from Google.In Collaboration WithSchool of ProgrammingMobile Web SpecialistConcepts CoveredMobile Web Apps, Web Tooling and Automation, Offline Capable Web Apps, Performant Web Apps, Asynchronous JavaScript RequestsIn Collaboration With advanced $1,199 USDLearn More(40)New!(40)Enroll by November 14Build effective machine learning models, run data pipelines, build recommendation systems, and deploy solutions to the cloud with industry-aligned projects.In Collaboration WithSchool of Data ScienceData ScientistIn Colla ...
#
#
# {&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerSpecialUrlLinks&a;locale=en-US&q;:[{&q;url&q;:&q;/built-on-blockchain&q;,&q;links&q;:[{&q;text&q;:&q;Home&q;,&q;href&q;:&q;/built-on-blockchain&q;},{&q;text&q;:&q;About&q;,&q;href&q;:&q;/built-on-blockchain/about&q;}]}],&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavLinks&a;locale=en-US&q;:[{&q;href&q;:&q;/courses/all&q;,&q;text&q;:&q;Catalog&q;},{&q;href&q;:&q;/pathfinder&q;,&q;text&q;:&q;Paths&q;},{&q;href&q;:&q;/nanodegree&q;,&q;text&q;:&q;Nanodegree&q;},{&q;href&q;:&q;/career-services&q;,&q;text&q;:&q;Career Help&q;},{&q;href&q;:&q;/enterprise&q;,&q;text&q;:&q;For Enterprise&q;}],&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavAuthMobileLinks&a;locale=en-US&q;:{&q;isAuth&q;:[{&q;text&q;:&q;Blog&q;,&q;href&q;:&q;http://blog.udacity.com/&q;},{&q;text&q;:&q;My Classroom&q;,&q;href&q;:&q;https://classroom.udacity.com/&q;,&q;classes&q;:[&q;blue&q;]}],&q;isNotAuth&q;:[{&q;text&q;:&q;Sign In&q;,&q;href&q;:&q;https://auth.udacity.com/sign-in?next=https://classroom.udacity.com/authenticated&q;,&q;classes&q;:[&q;blue&q;]},{&q;text&q;:&q;Get Started&q;,&q;href&q;:&q;https://auth.udacity.com/sign-up?next=https://classroom.udacity.com/authenticated&q;,&q;classes&q;:[&q;turquoise&q;]}]},&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavAuthLinks&a;locale=en-US&q;:{&q;isAuth&q;:[{&q;text&q;:&q;Blog&q;,&q;href&q;:&q;http://blog.udacity.com/&q;},{&q;text&q;:&q;My Classroom&q;,&q;href&q;:&q;https://classroom.udacity.com/&q;,&q;classes&q;:[&q;button--primary&q;]}],&q;isNotAuth&q;:[{&q;text&q;:&q;Sign In&q;,&q;href&q;:&q;https://auth.udacity.com/sign-in?next=https://classroom.udacity.com/authenticated&q;},{&q;text&q;:&q;Get Started&q;,&q;href&q;:&q;https://auth.udacity.com/sign-up?next=https://classroom.udacity.com/authenticated&q;,&q;classes&q;:[&q;button--primary&q;]}]},&q;/courses/all?experiment=%7B%22CATALOG_30_EXPERIMENT%22:%7B%22name%22:%22CATALOG_30_EXPERIMENT_V1_VARIANT_1%22,%22variant%22:%22VARIANT_1%22,%22active%22:true,%22props%22:%7B%7D,%22analytics%22:%7B%22variant_id%22:%221%22,%22experiment_id%22:%22cMqPkxoEQOaRL_twxbPBRA%22,%22media_query%22:%22%22,%22disableEarlyAnalytics%22:false%7D%7D%7D@CACHE_LOCALIZED_DATA-skillFilters&a;locale=en-US&q;:[{&q;section&q;:&q;Skills&q;,&q;values&q;:[{&q;title&q;:&q;AI Algorithms&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;AI Algorithms&q;}},{&q;title&q;:&q;AR development&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;AR development&q;}},{&q;title&q;:&q;ARKit&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;ARKit&q;}},{&q;title&q;:&q;Alteryx&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Alteryx&q;}},{&q;title&q;:&q;Android Development&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Android Development&q;}},{&q;title&q;:&q;Blueprint programming&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Blueprint programming&q;}},{&q;title&q;:&q;C++&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;C++&q;}},{&q;title&q;:&q;Career Advancement&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Career Advancement&q;}},{&q;title&q;:&q;CSS&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;CSS&q;}},{&q;title&q;:&q;Controls and Estimation&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Controls and Estimation&q;}},{&q;title&q;:&q;Core Data&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Core Data&q;}},{&q;t ...

# %%
from bs4 import BeautifulSoup

# Remove HTML tags using Beautiful Soup library
soup = BeautifulSoup(r.text, "html5lib")
print(soup.get_text())
# Out:
#
#   window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(15),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,s){try{p?p-=1:o(s||new UncaughtException(t,n,e),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t,n){var e=n?null:c.now();i("err",[t,e])}var i=t("handle"),a=t(16),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),d=!0)}s.on("fn-start",function(t,n,e){d&&(p+=1)}),s.on("fn-err",function(t,n,e){d&&!e[l]&&(f(e,l,function(){return!0}),this.thrown=!0,o(e))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&&(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof b&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(18)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o=t(18)(r);n.exports=r,o.inPlace(window.history,["pushState","replaceState"]," ...
# ;NREUM.info={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",licenseKey:"2059d2614a",applicationID:"215318720",sa:1}
#
#
#
#
#   window.DISABLE_EARLY_ANALYTICS = false;if (typeof Object.assign == 'function') {window.ACTIVE_EXPERIMENTS = window.ACTIVE_EXPERIMENTS || {};Object.assign(window.ACTIVE_EXPERIMENTS, {"CATALOG_30_EXPERIMENT":{"name":"CATALOG_30_EXPERIMENT_V1_VARIANT_1","variant":"VARIANT_1","active":true,"props":{},"analytics":{"variant_id":"1","experiment_id":"cMqPkxoEQOaRL_twxbPBRA","media_query":"","disableEarlyAnalytics":false}}});} else {window.ACTIVE_EXPERIMENTS = {"CATALOG_30_EXPERIMENT":{"name":"CATALOG_30_EXPERIMENT_V1_VARIANT_1","variant":"VARIANT_1","active":true,"props":{},"analytics":{"variant_id":"1","experiment_id":"cMqPkxoEQOaRL_twxbPBRA","media_query":"","disableEarlyAnalytics":false}}};}
# html[_ngcontent-sc0] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc0], *[_ngcontent-sc0]::after, *[_ngcontent-sc0]::before {
#   box-sizing: inherit; }
#
# a[_ngcontent-sc0] {
#   color: darkviolet; }
#
# body[_ngcontent-sc0] {
#   color: #028bb1; }
#
# [_nghost-sc0] {
#   display: block;
#   position: relative; }
#
# span.snackbar__content[_ngcontent-sc0] {
#   margin: 0;
#   color: white; }
#
# span.snackbar__content[_ngcontent-sc0]   a[_ngcontent-sc0] {
#     margin: 0;
#     color: white;
#     text-decoration: underline; }
#
# ir-header[_ngcontent-sc0], ir-new-header[_ngcontent-sc0] {
#   position: relative;
#   z-index: 7000; }
#
# .sticky.isFixed[_nghost-sc0]   ir-header[_ngcontent-sc0], .sticky.isFixed   [_nghost-sc0]   ir-header[_ngcontent-sc0], .sticky.isFixed[_nghost-sc0]   ir-new-header[_ngcontent-sc0], .sticky.isFixed   [_nghost-sc0]   ir-new-header[_ngcontent-sc0] {
#   top: auto; }
#
# @media screen and (min-width: 48rem) {
#     .sticky.isFixed[_nghost-sc0]   ir-header[_ngcontent-sc0], .sticky.isFixed   [_nghost-sc0]   ir-header[_ngcontent-sc0], .sticky.isFixed[_nghost-sc0]   ir-new-header[_ngcontent-sc0], .sticky.isFixed   [_nghost-sc0]   ir-new-header[_ngcontent-sc0] {
#       top: 52px; } }html[_ngcontent-sc1] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc1], *[_ngcontent-sc1]::after, *[_ngcontent-sc1]::before {
#   box-sizing: inherit; }
#
# .invisible[_ngcontent-sc1] {
#   visibility: hidden !important; }
#
# .hide[_ngcontent-sc1] {
#   display: none !important; }
#
# .show[_ngcontent-sc1] {
#   display: block !important; }
#
# .sr-only[_ngcontent-sc1] {
#   height: 1px;
#   width: 1px;
#   overflow: hidden;
#   position: absolute !important;
#   clip: rect(1px, 1px, 1px, 1px); }
#
# .hidden-xs-up[_ngcontent-sc1] {
#   display: none !important; }
#
# @media (max-width: 479px) {
#   .hidden-xs-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 480px) {
#   .hidden-sm-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (max-width: 767px) {
#   .hidden-sm-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 768px) {
#   .hidden-md-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (max-width: 991px) {
#   .hidden-md-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 992px) {
#   .hidden-lg-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (max-width: 1179px) {
#   .hidden-lg-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 1180px) {
#   .hidden-xl-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# .hidden-xl-down[_ngcontent-sc1] {
#   display: none !important; }
#
# .visible-print-block[_ngcontent-sc1] {
#   display: none !important; }
#
# @media print {
#     .visible-print-block[_ngcontent-sc1] {
#       display: block !important; } }
#
# .visible-print-inline[_ngcontent-sc1] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline[_ngcontent-sc1] {
#       display: inline !important; } }
#
# .visible-print-inline-block[_ngcontent-sc1] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline-block[_ngcontent-sc1] {
#       display: inline-block !important; } }
#
# @media print {
#   .hidden-print[_ngcontent-sc1] {
#     display: none !important; } }
#
# #contain-all[_ngcontent-sc1] {
#   width: 100%;
#   overflow: hidden;
#   background: #fff;
#   -webkit-backface-visibility: hidden;
#           backface-visibility: hidden;
#   -webkit-transform-style: preserve-3d; }
#
# .outer_contain[_ngcontent-sc1] {
#   margin: 0 auto;
#   max-width: 90rem; }
#
# .contain[_ngcontent-sc1] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto;
#   padding-top: 3rem;
#   padding-bottom: 3rem;
#   padding-left: 1.5rem;
#   padding-right: 1.5rem; }
#
# .contain[_ngcontent-sc1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# @media screen and (min-width: 48rem) {
#
#     .contain[_ngcontent-sc1] {
#       padding-top: 6rem;
#       padding-bottom: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#
#     .contain[_ngcontent-sc1] {
#       padding-left: 0;
#       padding-right: 0; } }
#
# .contain.no-padding[_ngcontent-sc1] {
#     padding: 0; }
#
# .contain.no-padding-top[_ngcontent-sc1] {
#     padding-top: 0; }
#
# .contain.no-padding-bottom[_ngcontent-sc1] {
#     padding-bottom: 0; }
#
# .contain--none[_ngcontent-sc1] {
#     padding-top: 0rem;
#     padding-bottom: 0rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--none[_ngcontent-sc1] {
#         padding-top: 0rem;
#         padding-bottom: 0rem; } }
#
# .contain--small[_ngcontent-sc1] {
#     padding-top: 3rem;
#     padding-bottom: 3rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--small[_ngcontent-sc1] {
#         padding-top: 4.5rem;
#         padding-bottom: 4.5rem; } }
#
# .cards_contain[_ngcontent-sc1] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto; }
#
# .cards_contain[_ngcontent-sc1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# [_ngcontent-sc1]:-webkit-full-screen-ancestor {
#   -webkit-animation: none !important;
#           animation: none !important;
#   -webkit-animation-fill-mode: none !important;
#   animation-fill-mode: none !important; }
#
# [_ngcontent-sc1]:target:before {
#   content: '';
#   display: inline-block;
#   height: 130px;
#   margin: -130px 0 0; }
#
# .header[_ngcontent-sc1] {
#   max-width: 100%;
#   margin-left: auto;
#   margin-right: auto; }
#
# .header[_ngcontent-sc1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# .header.header--clone[_ngcontent-sc1] {
#     width: 100%;
#     top: -1000px; }
#
# .header.header--clone[_ngcontent-sc1]   .header__navbar[_ngcontent-sc1] {
#       height: 4.5rem; }
#
# .header.header--stick[_ngcontent-sc1] {
#     top: 0;
#     background-color: #fff;
#     z-index: 8000;
#     box-shadow: 0px 1px 2px rgba(0, 0, 0, 0.1); }
#
# .header__navbar[_ngcontent-sc1] {
#     max-width: 73.75rem;
#     margin-left: auto;
#     margin-right: auto;
#     height: 4.5rem;
#     padding: 0 1.5em; }
#
# .header__navbar[_ngcontent-sc1]::after {
#       clear: both;
#       content: "";
#       display: table; }
#
# @media screen and (min-width: 48rem) {
#       .header__navbar[_ngcontent-sc1] {
#         height: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#       .header__navbar[_ngcontent-sc1] {
#         padding: 0; } }
#
# .header__navbar--toggle[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 15.25423729%; }
#
# .header__navbar--toggle[_ngcontent-sc1]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--toggle[_ngcontent-sc1] {
#           display: none; } }
#
# .header__navbar--logo[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 66.10169492%; }
#
# .header__navbar--logo[_ngcontent-sc1]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc1] {
#           float: left;
#           display: block;
#           margin-right: 0.84033613%;
#           width: 20.16806723%; }
#           .header__navbar--logo[_ngcontent-sc1]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--catalog[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--catalog[_ngcontent-sc1] {
#           float: left;
#           display: block;
#           margin-right: 0.84033613%;
#           width: 7.56302521%; }
#           .header__navbar--catalog[_ngcontent-sc1]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--navigation[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--navigation[_ngcontent-sc1] {
#           float: left;
#           display: block;
#           margin-right: 1.69491525%;
#           width: 74.57627119%; }
#           .header__navbar--navigation[_ngcontent-sc1]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--logo[_ngcontent-sc1] {
#     text-align: center; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--logo[_ngcontent-sc1] {
#         text-align: left; } }
#
# .header__navbar--logo[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#       width: 11.25rem;
#       height: 1.875rem;
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#           display: block; } }
#
# .header__navbar--logo[_ngcontent-sc1]   .logo-mark[_ngcontent-sc1] {
#       display: block;
#       margin: 0 auto;
#       width: 1.875rem;
#       height: 1.875rem; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc1]   .logo-mark[_ngcontent-sc1] {
#           display: none; } }
#
# .header__navbar--toggle[_ngcontent-sc1]   .nav-toggle[_ngcontent-sc1] {
#     display: block;
#     width: 1.25rem;
#     height: 1.25rem;
#     cursor: pointer;
#     transition: -webkit-transform .25s ease;
#     transition: transform .25s ease;
#     transition: transform .25s ease, -webkit-transform .25s ease; }
#
# .header__navbar--toggle[_ngcontent-sc1]   .nav-toggle[_ngcontent-sc1]   .bar[_ngcontent-sc1] {
#       display: block;
#       width: 100%;
#       height: 0.1875rem;
#       margin-left: -0.5rem;
#       margin-top: 0.1875rem;
#       background: #02b3e4;
#       transition: opacity .25s ease, -webkit-transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease, -webkit-transform .25s ease;
#       -webkit-user-select: none;
#          -moz-user-select: none;
#           -ms-user-select: none;
#               user-select: none; }
#
# .header__navbar--navigation[_ngcontent-sc1]   nav[_ngcontent-sc1] {
#     float: right; }
#
# .header__navbar--navigation[_ngcontent-sc1]   a[_ngcontent-sc1], .header__navbar--navigation[_ngcontent-sc1]   div[_ngcontent-sc1] {
#     float: left; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button[_ngcontent-sc1] {
#     display: none;
#     letter-spacing: 0;
#     font-size: 0.875rem;
#     text-transform: capitalize;
#     height: 2.25rem;
#     font-weight: 400;
#     margin-left: 2.5rem;
#     line-height: 1.9375rem; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button[_ngcontent-sc1]:first-child {
#       margin-left: 0; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--navigation[_ngcontent-sc1]   .button[_ngcontent-sc1] {
#         display: block; } }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--navigation[_ngcontent-sc1] {
#       padding: 0;
#       color: #525c65; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--navigation[_ngcontent-sc1]:hover {
#         color: #474f57; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--primary[_ngcontent-sc1], .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1] {
#       width: 7.75rem;
#       box-shadow: 8px 10px 20px 0px rgba(46, 61, 73, 0.15);
#       background-color: #02b3e4; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--primary[_ngcontent-sc1]:hover, .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1]:hover {
#         box-shadow: 2px 4px 8px 0px rgba(46, 61, 73, 0.2);
#         background-color: #02b7e9; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1] {
#       background-color: #02ccba; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1]:hover {
#         background-color: #02d1bf; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--guest[_ngcontent-sc1], .header__navbar--navigation[_ngcontent-sc1]   .button--student[_ngcontent-sc1] {
#       display: none; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .divider[_ngcontent-sc1] {
#     cursor: default; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .divider[_ngcontent-sc1]::before {
#       content: '';
#       border-left: 1px solid rgba(82, 92, 101, 0.4);
#       width: 0px;
#       height: 12px; }
#
# .header__sidenav[_ngcontent-sc1] {
#     background-color: #2e3d49; }
#
# .header__sidenav--logo[_ngcontent-sc1] {
#       height: 4.5rem;
#       display: block;
#       background-color: #1C262F; }
#
# .header__sidenav--logo[_ngcontent-sc1]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--logo[_ngcontent-sc1]   .logo-link[_ngcontent-sc1] {
#         display: block;
#         width: 100%;
#         height: 100%; }
#
# .header__sidenav--logo[_ngcontent-sc1]   .logo-link[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#           position: relative;
#           top: 50%;
#           -webkit-transform: translateY(-50%);
#           transform: translateY(-50%);
#           padding-left: 1.5em;
#           width: 11.25rem;
#           height: 1.875rem; }
#
# .header__sidenav--logo[_ngcontent-sc1]   .logo-link[_ngcontent-sc1]   #wordmark[_ngcontent-sc1] {
#           fill: #fff; }
#
# .header__sidenav--navigation[_ngcontent-sc1] {
#       display: block; }
#
# .header__sidenav--navigation[_ngcontent-sc1]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   li[_ngcontent-sc1] {
#         height: 4.5rem; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   a[_ngcontent-sc1] {
#         padding-top: 1.5rem;
#         padding-bottom: 1.5rem;
#         color: #fff;
#         display: block;
#         padding-left: 1.5em; }
#
# @media screen and (min-width: 48rem) {
#           .header__sidenav--navigation[_ngcontent-sc1]   a[_ngcontent-sc1] {
#             padding-top: 1.5rem;
#             padding-bottom: 1.5rem; } }
#
# .header__sidenav--navigation[_ngcontent-sc1]   a[_ngcontent-sc1]:hover {
#           color: #cccccc; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   .guest[_ngcontent-sc1], .header__sidenav--navigation[_ngcontent-sc1]   .student[_ngcontent-sc1] {
#         display: none; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   .guest[_ngcontent-sc1]   a[_ngcontent-sc1], .header__sidenav--navigation[_ngcontent-sc1]   .student[_ngcontent-sc1]   a[_ngcontent-sc1] {
#           color: #02b3e4; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   .guest[_ngcontent-sc1]   a[_ngcontent-sc1]:hover, .header__sidenav--navigation[_ngcontent-sc1]   .student[_ngcontent-sc1]   a[_ngcontent-sc1]:hover {
#             color: #01647f; }
#
# [_nghost-sc1] {
#   background: #2e3d49;
#   position: fixed;
#   top: 0;
#   left: 0;
#   height: 100vh;
#   display: block;
#   overflow-y: auto;
#   z-index: -1000;
#   width: 16.25rem;
#   -webkit-overflow-scrolling: touch;
#   display: block; }
#
# @media screen and (min-width: 62rem) {
#     [_nghost-sc1] {
#       display: none; } }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1] {
#     height: 4.5rem;
#     display: block;
#     background-color: #1C262F; }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1]::after {
#       clear: both;
#       content: "";
#       display: table; }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       padding-left: 1.5em;
#       width: 11.25rem;
#       height: 1.875rem; }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1]   #wordmark[_ngcontent-sc1] {
#       fill: #fff; }
#
# [_nghost-sc1]   ul[_ngcontent-sc1] {
#     list-style: none;
#     padding: 0; }
#
# .page-lg[_nghost-sc1], .page-lg   [_nghost-sc1] {
#   display: none; }html[_ngcontent-sc2] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc2], *[_ngcontent-sc2]::after, *[_ngcontent-sc2]::before {
#   box-sizing: inherit; }
#
# [_nghost-sc2] {
#   position: absolute;
#   width: 100%;
#   top: 0;
#   left: 0;
#   min-height: 100vh;
#   z-index: 0;
#   transition: -webkit-transform 0.3s ease;
#   transition: transform 0.3s ease;
#   transition: transform 0.3s ease, -webkit-transform 0.3s ease;
#   background: #fff; }
#
# .menu--open[_nghost-sc2]:not(.nav-experiment), .menu--open:not(.nav-experiment)   [_nghost-sc2] {
#   -webkit-transform: translateX(16.25rem);
#           transform: translateX(16.25rem); }
#
# .menu--open[_nghost-sc2], .menu--open   [_nghost-sc2] {
#   height: 100vh;
#   overflow: hidden; }
#
# @media screen and (min-width: 62rem) {
#     .menu--open[_nghost-sc2], .menu--open   [_nghost-sc2] {
#       overflow: auto;
#       -webkit-transform: none;
#               transform: none;
#       height: auto; } }
#
# .sticky[_nghost-sc2]:not(.no-sticky-header), .sticky:not(.no-sticky-header)   [_nghost-sc2] {
#   padding-top: 4.5rem; }
#
# @media screen and (min-width: 48rem) {
#     .sticky[_nghost-sc2]:not(.no-sticky-header), .sticky:not(.no-sticky-header)   [_nghost-sc2] {
#       padding-top: 6rem; } }
#
# .page-cn.page-school-of-data-science[_nghost-sc2], .page-cn.page-school-of-data-science   [_nghost-sc2] {
#   padding-top: 0; }
#
# .page-riseup[_nghost-sc2], .page-riseup   [_nghost-sc2] {
#   background: #2e3d49; }html[_ngcontent-sc3] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc3], *[_ngcontent-sc3]::after, *[_ngcontent-sc3]::before {
#   box-sizing: inherit; }
#
# [_nghost-sc3] {
#   display: block;
#   overflow: hidden; }
#
# .moustache[_ngcontent-sc3] {
#   position: relative;
#   width: 100%;
#   background: #fff;
#   padding: 0.75rem 2.5rem 0.75rem 1.5rem;
#   color: #fff;
#   text-align: center;
#   z-index: 8999; }
#
# .moustache[_ngcontent-sc3]   p[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     border-bottom: none; }
#
# .moustache[_ngcontent-sc3]   p[_ngcontent-sc3]   a.moustache__link--button[_ngcontent-sc3] {
#       border-bottom: 1px solid;
#       margin: 0 0.8rem; }
#
# .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #02b3e4;
#     display: inline-block;
#     margin: 0; }
#
# .moustache[_ngcontent-sc3]   .close-btn[_ngcontent-sc3] {
#     position: absolute;
#     top: 0;
#     right: 1rem;
#     bottom: 0;
#     display: flex;
#     background-color: transparent;
#     border: none;
#     outline: none;
#     opacity: 0.75;
#     margin: auto 0;
#     padding: 0;
#     color: #fff;
#     transition: opacity 0.3s ease; }
#
# .moustache[_ngcontent-sc3]   .close-btn[_ngcontent-sc3]   svg[_ngcontent-sc3] {
#       height: 0.8rem;
#       width: auto; }
#
# .moustache[_ngcontent-sc3]   .close-btn[_ngcontent-sc3]:hover {
#       opacity: 1; }
#
# .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #02b3e4; }
#
# .moustache.white[_ngcontent-sc3] {
#     background: #fff; }
#
# .moustache.white[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.white[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #02b3e4;
#       font-size: 1rem; }
#
# .moustache.white[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #02b3e4; }
#
# .moustache.blue[_ngcontent-sc3] {
#     background: #02b3e4; }
#
# .moustache.blue[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.blue[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.blue[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.blue-turquoise[_ngcontent-sc3] {
#     background: linear-gradient(to right, #02b3e4, #02ccba); }
#
# .moustache.blue-turquoise[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.blue-turquoise[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.blue-turquoise[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.purple-turquoise[_ngcontent-sc3] {
#     background: linear-gradient(to right, #a951ed, #02ccba); }
#
# .moustache.purple-turquoise[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.purple-turquoise[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.purple-turquoise[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.magenta-yellow[_ngcontent-sc3] {
#     background: linear-gradient(to right, #ff5483, #ffae0c); }
#
# .moustache.magenta-yellow[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.magenta-yellow[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.magenta-yellow[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.yellow-purple[_ngcontent-sc3] {
#     background: linear-gradient(to right, #ffae0c, #a951ed); }
#
# .moustache.yellow-purple[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.yellow-purple[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.yellow-purple[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.yellow-on-black[_ngcontent-sc3] {
#     background: #000; }
#
# .moustache.yellow-on-black[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.yellow-on-black[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #ffae0c;
#       font-size: 1rem; }
#
# .moustache.yellow-on-black[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #ffae0c; }
#
# .page-in.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-corporate[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-corporate   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-campaign[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-campaign   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-google-india-scholarships[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-google-india-scholarships   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-ucollege[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-ucollege   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   display: none; }
#
# .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   background: #02b3e4; }
#
# .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #fff;
#     font-size: 1rem; }
#
# .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #fff; }
#
# .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   background: #fff; }
#
# .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #02b3e4;
#     font-size: 1rem; }
#
# .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #02b3e4; }
#
# .page-cn.page-homepage.sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   background: #02b3e4; }
#
# .page-cn.page-homepage.sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #fff;
#     font-size: 1rem; }
#
# .page-cn.page-homepage.sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #fff; }
#
# .sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3], .sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   position: fixed;
#   z-index: 8001;
#   top: 0; }
#
# .page-cn.page-20181111[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn.page-20181111   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   display: none; }html[_ngcontent-sc4] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc4], *[_ngcontent-sc4]::after, *[_ngcontent-sc4]::before {
#   box-sizing: inherit; }
#
# .invisible[_ngcontent-sc4] {
#   visibility: hidden !important; }
#
# .hide[_ngcontent-sc4] {
#   display: none !important; }
#
# .show[_ngcontent-sc4] {
#   display: block !important; }
#
# .sr-only[_ngcontent-sc4] {
#   height: 1px;
#   width: 1px;
#   overflow: hidden;
#   position: absolute !important;
#   clip: rect(1px, 1px, 1px, 1px); }
#
# .hidden-xs-up[_ngcontent-sc4] {
#   display: none !important; }
#
# @media (max-width: 479px) {
#   .hidden-xs-down[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (min-width: 480px) {
#   .hidden-sm-up[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (max-width: 767px) {
#   .hidden-sm-down[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (min-width: 768px) {
#   .hidden-md-up[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (max-width: 991px) {
#   .hidden-md-down[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (min-width: 992px) {
#   .hidden-lg-up[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (max-width: 1179px) {
#   .hidden-lg-down[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (min-width: 1180px) {
#   .hidden-xl-up[_ngcontent-sc4] {
#     display: none !important; } }
#
# .hidden-xl-down[_ngcontent-sc4] {
#   display: none !important; }
#
# .visible-print-block[_ngcontent-sc4] {
#   display: none !important; }
#
# @media print {
#     .visible-print-block[_ngcontent-sc4] {
#       display: block !important; } }
#
# .visible-print-inline[_ngcontent-sc4] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline[_ngcontent-sc4] {
#       display: inline !important; } }
#
# .visible-print-inline-block[_ngcontent-sc4] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline-block[_ngcontent-sc4] {
#       display: inline-block !important; } }
#
# @media print {
#   .hidden-print[_ngcontent-sc4] {
#     display: none !important; } }
#
# #contain-all[_ngcontent-sc4] {
#   width: 100%;
#   overflow: hidden;
#   background: #fff;
#   -webkit-backface-visibility: hidden;
#           backface-visibility: hidden;
#   -webkit-transform-style: preserve-3d; }
#
# .outer_contain[_ngcontent-sc4] {
#   margin: 0 auto;
#   max-width: 90rem; }
#
# .contain[_ngcontent-sc4] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto;
#   padding-top: 3rem;
#   padding-bottom: 3rem;
#   padding-left: 1.5rem;
#   padding-right: 1.5rem; }
#
# .contain[_ngcontent-sc4]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# @media screen and (min-width: 48rem) {
#
#     .contain[_ngcontent-sc4] {
#       padding-top: 6rem;
#       padding-bottom: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#
#     .contain[_ngcontent-sc4] {
#       padding-left: 0;
#       padding-right: 0; } }
#
# .contain.no-padding[_ngcontent-sc4] {
#     padding: 0; }
#
# .contain.no-padding-top[_ngcontent-sc4] {
#     padding-top: 0; }
#
# .contain.no-padding-bottom[_ngcontent-sc4] {
#     padding-bottom: 0; }
#
# .contain--none[_ngcontent-sc4] {
#     padding-top: 0rem;
#     padding-bottom: 0rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--none[_ngcontent-sc4] {
#         padding-top: 0rem;
#         padding-bottom: 0rem; } }
#
# .contain--small[_ngcontent-sc4] {
#     padding-top: 3rem;
#     padding-bottom: 3rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--small[_ngcontent-sc4] {
#         padding-top: 4.5rem;
#         padding-bottom: 4.5rem; } }
#
# .cards_contain[_ngcontent-sc4] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto; }
#
# .cards_contain[_ngcontent-sc4]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# [_ngcontent-sc4]:-webkit-full-screen-ancestor {
#   -webkit-animation: none !important;
#           animation: none !important;
#   -webkit-animation-fill-mode: none !important;
#   animation-fill-mode: none !important; }
#
# [_ngcontent-sc4]:target:before {
#   content: '';
#   display: inline-block;
#   height: 130px;
#   margin: -130px 0 0; }
#
# .header[_ngcontent-sc4], [_nghost-sc4] {
#   max-width: 100%;
#   margin-left: auto;
#   margin-right: auto; }
#
# .header[_ngcontent-sc4]::after, [_nghost-sc4]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# .header.header--clone[_ngcontent-sc4], .header--clone[_nghost-sc4] {
#     width: 100%;
#     top: -1000px; }
#
# .header.header--clone[_ngcontent-sc4]   .header__navbar[_ngcontent-sc4], .header--clone[_nghost-sc4]   .header__navbar[_ngcontent-sc4], .header.header--clone[_ngcontent-sc4]   header[_ngcontent-sc4], .header--clone[_nghost-sc4]   header[_ngcontent-sc4] {
#       height: 4.5rem; }
#
# .header.header--stick[_ngcontent-sc4], .header--stick[_nghost-sc4] {
#     top: 0;
#     background-color: #fff;
#     z-index: 8000;
#     box-shadow: 0px 1px 2px rgba(0, 0, 0, 0.1); }
#
# .header__navbar[_ngcontent-sc4], header[_ngcontent-sc4] {
#     max-width: 73.75rem;
#     margin-left: auto;
#     margin-right: auto;
#     height: 4.5rem;
#     padding: 0 1.5em; }
#
# .header__navbar[_ngcontent-sc4]::after, header[_ngcontent-sc4]::after {
#       clear: both;
#       content: "";
#       display: table; }
#
# @media screen and (min-width: 48rem) {
#       .header__navbar[_ngcontent-sc4], header[_ngcontent-sc4] {
#         height: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#       .header__navbar[_ngcontent-sc4], header[_ngcontent-sc4] {
#         padding: 0; } }
#
# .header__navbar--toggle[_ngcontent-sc4] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 15.25423729%; }
#
# .header__navbar--toggle[_ngcontent-sc4]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--toggle[_ngcontent-sc4] {
#           display: none; } }
#
# .header__navbar--logo[_ngcontent-sc4] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 66.10169492%; }
#
# .header__navbar--logo[_ngcontent-sc4]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc4] {
#           float: left;
#           display: block;
#           margin-right: 0.84033613%;
#           width: 20.16806723%; }
#           .header__navbar--logo[_ngcontent-sc4]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--catalog[_ngcontent-sc4] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--catalog[_ngcontent-sc4] {
#           float: left;
#           display: block;
#           margin-right: 0.84033613%;
#           width: 7.56302521%; }
#           .header__navbar--catalog[_ngcontent-sc4]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--navigation[_ngcontent-sc4] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--navigation[_ngcontent-sc4] {
#           float: left;
#           display: block;
#           margin-right: 1.69491525%;
#           width: 74.57627119%; }
#           .header__navbar--navigation[_ngcontent-sc4]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--logo[_ngcontent-sc4] {
#     text-align: center; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--logo[_ngcontent-sc4] {
#         text-align: left; } }
#
# .header__navbar--logo[_ngcontent-sc4]   .logo-wordmark[_ngcontent-sc4], .header__navbar--logo[_ngcontent-sc4]   .logo-wordmark--cn[_ngcontent-sc4] {
#       width: 11.25rem;
#       height: 1.875rem;
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc4]   .logo-wordmark[_ngcontent-sc4], .header__navbar--logo[_ngcontent-sc4]   .logo-wordmark--cn[_ngcontent-sc4] {
#           display: block; } }
#
# .header__navbar--logo[_ngcontent-sc4]   .logo-mark[_ngcontent-sc4] {
#       display: block;
#       margin: 0 auto;
#       width: 1.875rem;
#       height: 1.875rem; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc4]   .logo-mark[_ngcontent-sc4] {
#           display: none; } }
#
# .header__navbar--toggle[_ngcontent-sc4]   .nav-toggle[_ngcontent-sc4] {
#     display: block;
#     width: 1.25rem;
#     height: 1.25rem;
#     cursor: pointer;
#     transition: -webkit-transform .25s ease;
#     transition: transform .25s ease;
#     transition: transform .25s ease, -webkit-transform .25s ease; }
#
# .header__navbar--toggle[_ngcontent-sc4]   .nav-toggle[_ngcontent-sc4]   .bar[_ngcontent-sc4] {
#       display: block;
#       width: 100%;
#       height: 0.1875rem;
#       margin-left: -0.5rem;
#       margin-top: 0.1875rem;
#       background: #02b3e4;
#       transition: opacity .25s ease, -webkit-transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease, -webkit-transform .25s ease;
#       -webkit-user-select: none;
#          -moz-user-select: none;
#           -ms-user-select: none;
#               user-select: none; }
#
# .header__navbar--navigation[_ngcontent-sc4]   nav[_ngcontent-sc4] {
#     float: right; }
#
# .header__navbar--navigation[_ngcontent-sc4]   a[_ngcontent-sc4], .header__navbar--navigation[_ngcontent-sc4]   div[_ngcontent-sc4] {
#     float: left; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button[_ngcontent-sc4] {
#     display: none;
#     letter-spacing: 0;
#     font-size: 0.875rem;
#     text-transform: capitalize;
#     height: 2.25rem;
#     font-weight: 400;
#     margin-left: 2.5rem;
#     line-height: 1.9375rem; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button[_ngcontent-sc4]:first-child {
#       margin-left: 0; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--navigation[_ngcontent-sc4]   .button[_ngcontent-sc4] {
#         display: block; } }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--navigation[_ngcontent-sc4] {
#       padding: 0;
#       color: #525c65; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--navigation[_ngcontent-sc4]:hover {
#         color: #474f57; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--primary[_ngcontent-sc4], .header__navbar--navigation[_ngcontent-sc4]   .button--turquoise[_ngcontent-sc4] {
#       width: 7.75rem;
#       box-shadow: 8px 10px 20px 0px rgba(46, 61, 73, 0.15);
#       background-color: #02b3e4; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--primary[_ngcontent-sc4]:hover, .header__navbar--navigation[_ngcontent-sc4]   .button--turquoise[_ngcontent-sc4]:hover {
#         box-shadow: 2px 4px 8px 0px rgba(46, 61, 73, 0.2);
#         background-color: #02b7e9; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--turquoise[_ngcontent-sc4] {
#       background-color: #02ccba; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--turquoise[_ngcontent-sc4]:hover {
#         background-color: #02d1bf; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--guest[_ngcontent-sc4], .header__navbar--navigation[_ngcontent-sc4]   .button--student[_ngcontent-sc4] {
#       display: none; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .divider[_ngcontent-sc4] {
#     cursor: default; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .divider[_ngcontent-sc4]::before {
#       content: '';
#       border-left: 1px solid rgba(82, 92, 101, 0.4);
#       width: 0px;
#       height: 12px; }
#
# .header__sidenav[_ngcontent-sc4] {
#     background-color: #2e3d49; }
#
# .header__sidenav--logo[_ngcontent-sc4] {
#       height: 4.5rem;
#       display: block;
#       background-color: #1C262F; }
#
# .header__sidenav--logo[_ngcontent-sc4]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--logo[_ngcontent-sc4]   .logo-link[_ngcontent-sc4] {
#         display: block;
#         width: 100%;
#         height: 100%; }
#
# .header__sidenav--logo[_ngcontent-sc4]   .logo-link[_ngcontent-sc4]   .logo-wordmark[_ngcontent-sc4], .header__sidenav--logo[_ngcontent-sc4]   .logo-link[_ngcontent-sc4]   .logo-wordmark--cn[_ngcontent-sc4] {
#           position: relative;
#           top: 50%;
#           -webkit-transform: translateY(-50%);
#           transform: translateY(-50%);
#           padding-left: 1.5em;
#           width: 11.25rem;
#           height: 1.875rem; }
#
# .header__sidenav--logo[_ngcontent-sc4]   .logo-link[_ngcontent-sc4]   #wordmark[_ngcontent-sc4] {
#           fill: #fff; }
#
# .header__sidenav--navigation[_ngcontent-sc4] {
#       display: block; }
#
# .header__sidenav--navigation[_ngcontent-sc4]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   li[_ngcontent-sc4] {
#         height: 4.5rem; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   a[_ngcontent-sc4] {
#         padding-top: 1.5rem;
#         padding-bottom: 1.5rem;
#         color: #fff;
#         display: block;
#         padding-left: 1.5em; }
#
# @media screen and (min-width: 48rem) {
#           .header__sidenav--navigation[_ngcontent-sc4]   a[_ngcontent-sc4] {
#             padding-top: 1.5rem;
#             padding-bottom: 1.5rem; } }
#
# .header__sidenav--navigation[_ngcontent-sc4]   a[_ngcontent-sc4]:hover {
#           color: #cccccc; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   .guest[_ngcontent-sc4], .header__sidenav--navigation[_ngcontent-sc4]   .student[_ngcontent-sc4] {
#         display: none; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   .guest[_ngcontent-sc4]   a[_ngcontent-sc4], .header__sidenav--navigation[_ngcontent-sc4]   .student[_ngcontent-sc4]   a[_ngcontent-sc4] {
#           color: #02b3e4; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   .guest[_ngcontent-sc4]   a[_ngcontent-sc4]:hover, .header__sidenav--navigation[_ngcontent-sc4]   .student[_ngcontent-sc4]   a[_ngcontent-sc4]:hover {
#             color: #01647f; }
#
# html[_ngcontent-sc4] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc4], *[_ngcontent-sc4]::after, *[_ngcontent-sc4]::before {
#   box-sizing: inherit; }
#
# [_nghost-sc4] {
#   display: block;
#   z-index: 1;
#   position: relative; }
#
# header[_ngcontent-sc4]   .header__navbar--navigation[_ngcontent-sc4] {
#   float: right; }
#
# @-webkit-keyframes sticky-slide-down {
#   100% {
#     -webkit-transform: translateY(0);
#             transform: translateY(0); } }
#
# @keyframes sticky-slide-down {
#   100% {
#     -webkit-transform: translateY(0);
#             transform: translateY(0); } }
#
# .header-icons[_ngcontent-sc4] {
#   display: block;
#   position: relative;
#   top: 1.4rem;
#   float: right;
#   margin-right: -0.7rem; }
#
# .header-icons[_ngcontent-sc4]   svg[_ngcontent-sc4] {
#     height: 1.8rem;
#     fill: #02b3e4; }
#
# @media screen and (min-width: 30rem) {
#     .header-icons[_ngcontent-sc4] {
#       display: none; } }
#
# .phone-icon[_ngcontent-sc4] {
#   display: none;
#   line-height: 0; }
#
# .show-sales-widget[_nghost-sc4]   .phone-icon[_ngcontent-sc4], .show-sales-widget   [_nghost-sc4]   .phone-icon[_ngcontent-sc4] {
#   display: block;
#   position: relative;
#   top: 1.4rem;
#   float: right;
#   margin-right: -0.7rem;
#   top: 50%;
#   -webkit-transform: translateY(-50%);
#           transform: translateY(-50%); }
#
# .show-sales-widget[_nghost-sc4]   .phone-icon[_ngcontent-sc4]   svg[_ngcontent-sc4], .show-sales-widget   [_nghost-sc4]   .phone-icon[_ngcontent-sc4]   svg[_ngcontent-sc4] {
#     height: 1.8rem;
#     fill: #02b3e4; }
#
# @media screen and (min-width: 30rem) {
#     .show-sales-widget[_nghost-sc4]   .phone-icon[_ngcontent-sc4], .show-sales-widget   [_nghost-sc4]   .phone-icon[_ngcontent-sc4] {
#       display: none; } }
#
# .page-homepage[_nghost-sc4]   .logo-wordmark[_ngcontent-sc4]   h1[_ngcontent-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-homepage   [_nghost-sc4]   .logo-wordmark[_ngcontent-sc4]   h1[_ngcontent-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-homepage[_nghost-sc4]   .logo-wordmark--cn[_ngcontent-sc4]   h1[_ngcontent-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-homepage   [_nghost-sc4]   .logo-wordmark--cn[_ngcontent-sc4]   h1[_ngcontent-sc4]   img.logo-wordmark--img[_ngcontent-sc4] {
#   padding-bottom: 1.5rem;
#   width: 180px; }
#
# .page-homepage[_nghost-sc4]   .logo-wordmark--cn[_ngcontent-sc4]   h1[_ngcontent-sc4], .page-homepage   [_nghost-sc4]   .logo-wordmark--cn[_ngcontent-sc4]   h1[_ngcontent-sc4] {
#   margin-bottom: 0; }
#
# .page-eu.page-homepage[_nghost-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-eu.page-homepage   [_nghost-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-in.page-homepage[_nghost-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-in.page-homepage   [_nghost-sc4]   img.logo-wordmark--img[_ngcontent-sc4] {
#   padding-bottom: 1.5rem; }
#
# .experiment-cro-br-header[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .experiment-cro-br-header   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .experiment-cro-br-header[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .experiment-cro-br-header   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .experiment-cro-br-header[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .experiment-cro-br-header   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .experiment-cro-br-header[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .experiment-cro-br-header   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .experiment-cro-br-header[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .experiment-cro-br-header   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .experiment-cro-br-header[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .experiment-cro-br-header   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .experiment-cro-br-header[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #mark[_ngcontent-sc4], .experiment-cro-br-header   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #mark[_ngcontent-sc4], .experiment-cro-br-header[_nghost-sc4]   header[_ngcontent-sc4]   #mark[_ngcontent-sc4], .experiment-cro-br-header   [_nghost-sc4]   header[_ngcontent-sc4]   #mark[_ngcontent-sc4] {
#   fill: #fff; }
#
# .experiment-cro-br-header[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .experiment-cro-br-header   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .experiment-cro-br-header[_nghost-sc4]   header[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .experiment-cro-br-header   [_nghost-sc4]   header[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4] {
#   stroke: #fff; }
#
# ...
#         margin: 0;
#         color: #525c65; }
#
# .primary-menu-mobile[_nghost-sc17]   .catalog-nav[_ngcontent-sc17], .primary-menu-mobile   [_nghost-sc17]   .catalog-nav[_ngcontent-sc17] {
#   color: #fff;
#   display: block;
#   padding-left: 1.5em;
#   display: block;
#   padding-top: 1.5rem;
#   padding-bottom: 1.5rem; }
#
# .primary-menu-mobile[_nghost-sc17]   .catalog-nav[_ngcontent-sc17]::after, .primary-menu-mobile   [_nghost-sc17]   .catalog-nav[_ngcontent-sc17]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# @media screen and (min-width: 48rem) {
#     .primary-menu-mobile[_nghost-sc17]   .catalog-nav[_ngcontent-sc17], .primary-menu-mobile   [_nghost-sc17]   .catalog-nav[_ngcontent-sc17] {
#       padding-top: 1.5rem;
#       padding-bottom: 1.5rem; } }
#
# .primary-menu-mobile[_nghost-sc17]   .catalog-nav[_ngcontent-sc17]:hover, .primary-menu-mobile   [_nghost-sc17]   .catalog-nav[_ngcontent-sc17]:hover {
#     cursor: pointer;
#     color: #cccccc; }
#
# .primary-menu-mobile[_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17], .primary-menu-mobile   [_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17] {
#     height: 100%;
#     position: absolute;
#     list-style: none;
#     padding: 0;
#     background-color: #2e3d49;
#     top: 0;
#     left: -16.25rem;
#     width: 16.25rem;
#     transition: 0.5s; }
#
# .primary-menu-mobile[_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu.active[_ngcontent-sc17], .primary-menu-mobile   [_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu.active[_ngcontent-sc17] {
#       left: 0; }
#
# .primary-menu-mobile[_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .li[_ngcontent-sc17], .primary-menu-mobile   [_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .li[_ngcontent-sc17] {
#       height: 4.5rem; }
#
# .primary-menu-mobile[_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .secondary-menu-item[_ngcontent-sc17], .primary-menu-mobile   [_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .secondary-menu-item[_ngcontent-sc17], .primary-menu-mobile[_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .secondary-menu-item--header[_ngcontent-sc17], .primary-menu-mobile   [_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .secondary-menu-item--header[_ngcontent-sc17] {
#       padding-top: 1.5rem;
#       padding-bottom: 1.5rem;
#       color: #fff;
#       display: block;
#       padding-left: 1.5rem;
#       padding-right: 1.5rem; }
#
# @media screen and (min-width: 48rem) {
#         .primary-menu-mobile[_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .secondary-menu-item[_ngcontent-sc17], .primary-menu-mobile   [_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .secondary-menu-item[_ngcontent-sc17], .primary-menu-mobile[_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .secondary-menu-item--header[_ngcontent-sc17], .primary-menu-mobile   [_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .secondary-menu-item--header[_ngcontent-sc17] {
#           padding-top: 1.5rem;
#           padding-bottom: 1.5rem; } }
#
# .primary-menu-mobile[_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .secondary-menu-item[_ngcontent-sc17]   h6[_ngcontent-sc17], .primary-menu-mobile   [_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .secondary-menu-item[_ngcontent-sc17]   h6[_ngcontent-sc17], .primary-menu-mobile[_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .secondary-menu-item--header[_ngcontent-sc17]   h6[_ngcontent-sc17], .primary-menu-mobile   [_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .secondary-menu-item--header[_ngcontent-sc17]   h6[_ngcontent-sc17] {
#         color: #fff;
#         margin: 0; }
#
# .primary-menu-mobile[_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .secondary-menu-item[_ngcontent-sc17]:hover, .primary-menu-mobile   [_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .secondary-menu-item[_ngcontent-sc17]:hover {
#       color: #cccccc;
#       cursor: pointer; }
#
# .primary-menu-mobile[_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .secondary-menu-item[_ngcontent-sc17]   .back-icon[_ngcontent-sc17], .primary-menu-mobile   [_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .secondary-menu-item[_ngcontent-sc17]   .back-icon[_ngcontent-sc17] {
#       position: relative;
#       float: left;
#       top: -4px; }
#
# .primary-menu-mobile[_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .secondary-menu-item[_ngcontent-sc17]   .nav-back[_ngcontent-sc17], .primary-menu-mobile   [_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .secondary-menu-item[_ngcontent-sc17]   .nav-back[_ngcontent-sc17] {
#       float: left;
#       left: 0.5rem;
#       position: relative; }
#
# .primary-menu-mobile[_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .secondary-menu-item--header[_ngcontent-sc17]:hover, .primary-menu-mobile   [_nghost-sc17]   .catalog-nav[_ngcontent-sc17]   .catalog-nav--menu[_ngcontent-sc17]   .secondary-menu-item--header[_ngcontent-sc17]:hover {
#       cursor: default; }html[_ngcontent-sc343] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc343], *[_ngcontent-sc343]::after, *[_ngcontent-sc343]::before {
#   box-sizing: inherit; }
#
# html[_ngcontent-sc343] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc343], *[_ngcontent-sc343]::after, *[_ngcontent-sc343]::before {
#   box-sizing: inherit; }
#
# .invisible[_ngcontent-sc343] {
#   visibility: hidden !important; }
#
# .hide[_ngcontent-sc343] {
#   display: none !important; }
#
# .show[_ngcontent-sc343] {
#   display: block !important; }
#
# .sr-only[_ngcontent-sc343] {
#   height: 1px;
#   width: 1px;
#   overflow: hidden;
#   position: absolute !important;
#   clip: rect(1px, 1px, 1px, 1px); }
#
# .hidden-xs-up[_ngcontent-sc343] {
#   display: none !important; }
#
# @media (max-width: 479px) {
#   .hidden-xs-down[_ngcontent-sc343] {
#     display: none !important; } }
#
# @media (min-width: 480px) {
#   .hidden-sm-up[_ngcontent-sc343] {
#     display: none !important; } }
#
# @media (max-width: 767px) {
#   .hidden-sm-down[_ngcontent-sc343] {
#     display: none !important; } }
#
# @media (min-width: 768px) {
#   .hidden-md-up[_ngcontent-sc343] {
#     display: none !important; } }
#
# @media (max-width: 991px) {
#   .hidden-md-down[_ngcontent-sc343] {
#     display: none !important; } }
#
# @media (min-width: 992px) {
#   .hidden-lg-up[_ngcontent-sc343] {
#     display: none !important; } }
#
# @media (max-width: 1179px) {
#   .hidden-lg-down[_ngcontent-sc343] {
#     display: none !important; } }
#
# @media (min-width: 1180px) {
#   .hidden-xl-up[_ngcontent-sc343] {
#     display: none !important; } }
#
# .hidden-xl-down[_ngcontent-sc343] {
#   display: none !important; }
#
# .visible-print-block[_ngcontent-sc343] {
#   display: none !important; }
#
# @media print {
#     .visible-print-block[_ngcontent-sc343] {
#       display: block !important; } }
#
# .visible-print-inline[_ngcontent-sc343] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline[_ngcontent-sc343] {
#       display: inline !important; } }
#
# .visible-print-inline-block[_ngcontent-sc343] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline-block[_ngcontent-sc343] {
#       display: inline-block !important; } }
#
# @media print {
#   .hidden-print[_ngcontent-sc343] {
#     display: none !important; } }
#
# .card[_ngcontent-sc343] {
#   background: #fff;
#   box-shadow: 2px 4px 8px rgba(46, 61, 73, 0.2);
#   border-radius: 0.375rem;
#   overflow: hidden;
#   width: 100%;
#   height: 100%;
#   cursor: pointer;
#   display: flex;
#   min-height: 26.5rem;
#   position: relative;
#   flex-direction: column;
#   justify-content: flex-start; }
#
# .card--red[_ngcontent-sc343]   .card__image[_ngcontent-sc343] {
#     border-color: #ff5483;
#     background-color: #99324f; }
#
# .card--purple[_ngcontent-sc343]   .card__image[_ngcontent-sc343] {
#     border-color: #a951ed;
#     background-color: #65318e; }
#
# .card--yellow[_ngcontent-sc343]   .card__image[_ngcontent-sc343] {
#     border-color: #ecc81a;
#     background-color: #8e7810; }
#
# .card--green[_ngcontent-sc343]   .card__image[_ngcontent-sc343] {
#     border-color: #02ccba;
#     background-color: #017a70; }
#
# .card--pink[_ngcontent-sc343]   .card__image[_ngcontent-sc343] {
#     border-color: #FF8BAB;
#     background-color: #995367; }
#
# .card.empty[_ngcontent-sc343] {
#     display: flex;
#     align-items: center;
#     justify-content: center; }
#
# @media screen and (min-width: 48rem) {
#     .card[_ngcontent-sc343] {
#       cursor: default; }
#       .card[_ngcontent-sc343]:not(.disabled) {
#         cursor: pointer; }
#         .card[_ngcontent-sc343]:not(.disabled):hover   .card__overlay[_ngcontent-sc343] {
#           display: flex; } }
#
# .card__container[_ngcontent-sc343] {
#     padding: 0.5rem 1.25rem; }
#
# .card__content[_ngcontent-sc343] {
#     flex: 1;
#     position: relative; }
#
# @media screen and (min-width: 48rem) {
#       .card__content[_ngcontent-sc343] {
#         position: initial; } }
#
# .card__level[_ngcontent-sc343] {
#     color: #647381;
#     text-transform: capitalize;
#     margin-bottom: 1.125rem;
#     font-size: 0.875rem;
#     margin-left: 1.25rem; }
#
# .card__level[_ngcontent-sc343]   svg[_ngcontent-sc343] {
#       margin-right: 0.4375rem; }
#
# .card__image[_ngcontent-sc343] {
#     width: 100%;
#     height: 7.8125rem;
#     display: block;
#     position: relative;
#     flex-shrink: 0;
#     background-color: #525c65;
#     background-image: url("/assets/iridium/images/course-catalog/card-bg.png");
#     border-bottom-style: solid;
#     border-bottom-width: 0.5rem;
#     border-bottom-color: #7d97ad;
#     background-size: cover;
#     background-repeat: no-repeat;
#     background-position: center; }
#
# .card__image.dimmed[_ngcontent-sc343]:after {
#       background: linear-gradient(-8deg, rgba(0, 0, 0, 0) 27%, rgba(0, 0, 0, 0.6) 79%); }
#
# .card__image[_ngcontent-sc343]:after {
#       content: '';
#       width: 100%;
#       height: 100%;
#       position: absolute;
#       top: 0;
#       left: 0; }
#
# .card__school[_ngcontent-sc343] {
#     color: #6d7780;
#     margin: 0.6rem 0 0;
#     line-height: 2em;
#     font-size: 0.75rem;
#     font-weight: 600; }
#
# @media screen and (min-width: 48rem) {
#       .card__school[_ngcontent-sc343] {
#         font-size: 0.875rem;
#         line-height: 1.75rem; } }
#
# .card__overlay[_ngcontent-sc343] {
#     display: none;
#     background: rgba(0, 0, 0, 0.9);
#     width: 100%;
#     height: calc(100% - 48px);
#     position: absolute;
#     top: 0;
#     left: 0;
#     text-align: center;
#     color: #fff;
#     flex-direction: column;
#     align-items: center;
#     justify-content: space-between; }
#
# @media screen and (min-width: 48rem) {
#       .card__overlay[_ngcontent-sc343]   .card__rating[_ngcontent-sc343] {
#         display: block;
#         position: relative; } }
#
# .card__overlay[_ngcontent-sc343]:hover {
#       display: flex; }
#
# .card__overlay__summary[_ngcontent-sc343] {
#       margin: 0 2rem;
#       flex: 1;
#       display: flex;
#       flex-direction: column;
#       justify-content: flex-start;
#       padding-top: 2rem;
#       line-height: 1.6rem;
#       color: #fff;
#       font-size: 0.75rem; }
#
# .card__overlay__summary[_ngcontent-sc343]   p[_ngcontent-sc343] {
#         margin: 0;
#         padding: 0;
#         line-height: inherit;
#         color: inherit;
#         font-size: inherit; }
#
# .card__overlay[_ngcontent-sc343]   span.card__overlay__enrollBy[_ngcontent-sc343] {
#       letter-spacing: 0;
#       line-height: 2rem;
#       height: 2rem;
#       text-transform: none;
#       font-size: 1rem;
#       font-weight: 600; }
#
# .card__tag[_ngcontent-sc343] {
#     color: #fff;
#     position: absolute;
#     top: 1rem;
#     left: 1rem;
#     line-height: 1em;
#     font-weight: 700;
#     font-size: 0.875rem; }
#
# .card__rating[_ngcontent-sc343] {
#     position: absolute;
#     top: 0;
#     right: 1rem;
#     color: #fff;
#     z-index: 99; }
#
# @media screen and (min-width: 48rem) {
#       .card__rating[_ngcontent-sc343] {
#         display: none;
#         right: 0; } }
#
# .card__stars[_ngcontent-sc343] {
#     display: inline-block;
#     margin: 0 auto;
#     height: 0.75rem;
#     width: 4.78125rem;
#     margin-top: 1rem;
#     margin-right: 0.4rem;
#     position: relative;
#     background-image: url("/assets/iridium/images/course-catalog/stars-white.svg");
#     background-position: 0 0;
#     background-size: 4.78125rem 1.5rem;
#     background-repeat: no-repeat; }
#
# @media screen and (min-width: 48rem) {
#       .card__stars[_ngcontent-sc343] {
#         margin-top: 2.6rem; } }
#
# .card__stars__fill[_ngcontent-sc343] {
#       position: absolute;
#       top: 0;
#       left: 0;
#       height: 100%;
#       background-image: url("/assets/iridium/images/course-catalog/stars-white.svg");
#       background-position: 0 -0.75rem;
#       background-size: 4.78125rem 1.5rem;
#       background-repeat: no-repeat; }
#
# .card__logos[_ngcontent-sc343] {
#     display: flex;
#     justify-content: center;
#     align-items: center;
#     flex-wrap: wrap; }
#
# .card__logos[_ngcontent-sc343]   img[_ngcontent-sc343] {
#       height: 2.9375rem;
#       margin: 0 1.5rem; }
#
# .card__title[_ngcontent-sc343] {
#     color: #2e3d49;
#     line-height: 1.3em;
#     font-size: 1.5rem;
#     font-weight: 800; }
#
# @media screen and (min-width: 48rem) {
#       .card__title[_ngcontent-sc343] {
#         font-size: 1.5rem; } }
#
# .card__collaboration[_ngcontent-sc343] {
#     letter-spacing: 0.09375rem;
#     text-transform: uppercase;
#     line-height: 2em;
#     margin: 2rem 0;
#     font-size: 0.75rem;
#     font-weight: 600; }
#
# .card__collaboration--mobile[_ngcontent-sc343] {
#       display: block;
#       margin: 0; }
#
# .card__collaboration--mobile[_ngcontent-sc343]   .h6[_ngcontent-sc343] {
#         font-weight: 400; }
#
# @media screen and (min-width: 48rem) {
#         .card__collaboration--mobile[_ngcontent-sc343] {
#           display: none; } }
#
# .card__collaboration--mobile[_ngcontent-sc343]    > .card__logos[_ngcontent-sc343] {
#         display: flex;
#         justify-content: flex-start;
#         align-items: center;
#         margin-bottom: 1rem; }
#
# .card__collaboration--mobile[_ngcontent-sc343]    > .card__logos[_ngcontent-sc343]   img[_ngcontent-sc343] {
#           margin: 0 1rem;
#           max-height: 1.8125rem; }
#
# .card__collaboration--mobile[_ngcontent-sc343]    > .card__logos[_ngcontent-sc343]   img[_ngcontent-sc343]:first-of-type {
#             margin-left: 0; }
#
# .card__concepts[_ngcontent-sc343]   h6[_ngcontent-sc343] {
#     font-weight: 400;
#     margin: 0;
#     padding: 0;
#     line-height: 2rem;
#     font-size: 1rem; }
#
# .card__footer[_ngcontent-sc343] {
#     background: #02b3e4;
#     padding: 0 1.25rem;
#     height: 3rem;
#     color: #fff;
#     display: flex;
#     flex-shrink: 0;
#     flex-direction: row;
#     justify-content: space-between;
#     align-items: center;
#     z-index: 1000; }
#
# .card__button[_ngcontent-sc343] {
#     background: none;
#     border: none;
#     height: auto;
#     letter-spacing: 0.045625rem;
#     color: #fff;
#     position: relative;
#     margin-right: 1rem;
#     font-weight: 600;
#     font-size: 0.8125rem; }
#
# .card__button[_ngcontent-sc343]:after {
#       content: '';
#       width: 0.9375rem;
#       height: 100%;
#       display: block;
#       background-image: url(/assets/iridium/images/course-catalog/icon-white-arrow.svg);
#       background-position: center;
#       background-repeat: no-repeat;
#       position: absolute;
#       right: -0.9375rem;
#       top: 0; }

# %%
# Find all course summaries
summaries = soup.find_all("div", class_="course-summary-card")
summaries[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-6d77aded2f75> in <module>()
#       1 # Find all course summaries
#       2 summaries = soup.find_all("div", class_="course-summary-card")
# ----> 3 summaries[0]
#
# IndexError: list index out of range

# %%
# Extract title
summaries[0].select_one("h3 a").get_text().strip()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-0a50e9f541b4> in <module>()
#       1 # Extract title
# ----> 2 summaries[0].select_one("h3 a").get_text().strip()
#
# IndexError: list index out of range

# %%
# Extract description
summaries[0].select_one("div[data-course-short-summary]").get_text().strip()

# %%
# Find all course summaries, extract title and description
courses = []
summaries = soup.find_all("div", class_="course-summary-card")
for summary in summaries:
    title = summary.select_one("h3 a").get_text().strip()
    description = summary.select_one("div[data-course-short-summary]").get_text().strip()
    courses.append((title, description))

print(len(courses), "course summaries found. Sample:")
print(courses[0][0])
print(courses[0][1])
# Out:
# 0 course summaries found. Sample:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-e74f468d3561> in <module>()
#       8
#       9 print(len(courses), "course summaries found. Sample:")
# ---> 10 print(courses[0][0])
#      11 print(courses[0][1])
#
# IndexError: list index out of range

# %% [markdown]
# ## Normalization

# %% [markdown]
# ### Case Normalization

# %%
# Sample text
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"
print(text)
# Out:
# The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?

# %%
# Convert to lowercase
text = text.lower() 
print(text)
# Out:
# the first time you see the second renaissance it may look boring. look at it at least twice and definitely watch part 2. it will change your view of the matrix. are the human people the ones who started the war ? is ai a bad thing ?

# %% [markdown]
# ### Punctuation Removal

# %%
import re

# Remove punctuation characters
text = re.sub(r"[^a-zA-Z0-9]", " ", text) 
print(text)
# Out:
# the first time you see the second renaissance it may look boring  look at it at least twice and definitely watch part 2  it will change your view of the matrix  are the human people the ones who started the war   is ai a bad thing

# %% [markdown]
# ## Tokenization

# %%
# Split text into tokens (words)
words = text.split()
print(words)
# Out:
# ['the', 'first', 'time', 'you', 'see', 'the', 'second', 'renaissance', 'it', 'may', 'look', 'boring', 'look', 'at', 'it', 'at', 'least', 'twice', 'and', 'definitely', 'watch', 'part', '2', 'it', 'will', 'change', 'your', 'view', 'of', 'the', 'matrix', 'are', 'the', 'human', 'people', 'the', 'ones', 'who', 'started', 'the', 'war', 'is', 'ai', 'a', 'bad', 'thing']

# %% [markdown]
# ### NLTK: Natural Language ToolKit

# %%
# Another sample text
text = "Dr. Smith graduated from the University of Washington. He later started an analytics firm called Lux, which catered to enterprise customers."
print(text)
# Out:
# Dr. Smith graduated from the University of Washington. He later started an analytics firm called Lux, which catered to enterprise customers.

# %%
from nltk.tokenize import word_tokenize

# Split text into words using NLTK
words = word_tokenize(text)
print(words)
# Out:
# ['Dr.', 'Smith', 'graduated', 'from', 'the', 'University', 'of', 'Washington', '.', 'He', 'later', 'started', 'an', 'analytics', 'firm', 'called', 'Lux', ',', 'which', 'catered', 'to', 'enterprise', 'customers', '.']

# %%
from nltk.tokenize import sent_tokenize

# Split text into sentences
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Dr. Smith graduated from the University of Washington.', 'He later started an analytics firm called Lux, which catered to enterprise customers.']

# %%
# List stop words
from nltk.corpus import stopwords
print(stopwords.words("english"))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'couldn', 'didn', 'doesn', 'hadn', 'hasn', 'haven', 'isn', 'ma', 'mightn', 'mustn', 'needn', 'shan', 'shouldn', 'wasn', 'weren', 'won', 'wouldn']

# %%
# Reset text
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"

# Normalize it
text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())

# Tokenize it
words = text.split()
print(words)
# Out:
# ['the', 'first', 'time', 'you', 'see', 'the', 'second', 'renaissance', 'it', 'may', 'look', 'boring', 'look', 'at', 'it', 'at', 'least', 'twice', 'and', 'definitely', 'watch', 'part', '2', 'it', 'will', 'change', 'your', 'view', 'of', 'the', 'matrix', 'are', 'the', 'human', 'people', 'the', 'ones', 'who', 'started', 'the', 'war', 'is', 'ai', 'a', 'bad', 'thing']

# %%
# Remove stop words
words = [w for w in words if w not in stopwords.words("english")]
print(words)
# Out:
# ['first', 'time', 'see', 'second', 'renaissance', 'may', 'look', 'boring', 'look', 'least', 'twice', 'definitely', 'watch', 'part', '2', 'change', 'view', 'matrix', 'human', 'people', 'ones', 'started', 'war', 'ai', 'bad', 'thing']

# %% [markdown]
# ## Part-of-Speech Tagging

# %%
from nltk import pos_tag

# Tag parts of speech (PoS)
sentence = word_tokenize("I always lie down to tell a lie.")
pos_tag(sentence)
# Out:
# [('I', 'PRP'),
#  ('always', 'RB'),
#  ('lie', 'VBP'),
#  ('down', 'RP'),
#  ('to', 'TO'),
#  ('tell', 'VB'),
#  ('a', 'DT'),
#  ('lie', 'NN'),
#  ('.', '.')]

# %% [markdown]
# ### Sentence Parsing

# %%
import nltk

# Define a custom grammar
my_grammar = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'an' | 'my'
N -> 'elephant' | 'pajamas'
V -> 'shot'
P -> 'in'
""")
parser = nltk.ChartParser(my_grammar)

# Parse a sentence
sentence = word_tokenize("I shot an elephant in my pajamas")
for tree in parser.parse(sentence):
    print(tree)
# Out:
# (S
#   (NP I)
#   (VP
#     (VP (V shot) (NP (Det an) (N elephant)))
#     (PP (P in) (NP (Det my) (N pajamas)))))
# (S
#   (NP I)
#   (VP
#     (V shot)
#     (NP (Det an) (N elephant) (PP (P in) (NP (Det my) (N pajamas))))))

# %%
import IPython  # for displaying parse trees inline

# Visualize parse trees
for tree in parser.parse(sentence):
    IPython.display.display(tree)  # instead of tree.draw()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /Users/tomdunlap/anaconda3/envs/dl/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# /Users/tomdunlap/anaconda3/envs/dl/lib/python3.6/site-packages/nltk/tree.py in _repr_png_(self)
#     728             _canvas_frame.print_to_file(in_path)
#     729             _canvas_frame.destroy_widget(widget)
# --> 730             subprocess.call([find_binary('gs', binary_names=['gswin32c.exe', 'gswin64c.exe'], env_vars=['PATH'], verbose=False)] +
#     731                             '-q -dEPSCrop -sDEVICE=png16m -r90 -dTextAlphaBits=4 -dGraphicsAlphaBits=4 -dSAFER -dBATCH -dNOPAUSE -sOutputFile={0:} {1:}'
#     732                             .format(out_path, in_path).split())
#
# /Users/tomdunlap/anaconda3/envs/dl/lib/python3.6/site-packages/nltk/__init__.py in find_binary(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     602                 binary_names=None, url=None, verbose=False):
#     603     return next(find_binary_iter(name, path_to_bin, env_vars, searchpath,
# --> 604                                  binary_names, url, verbose))
#     605
#     606 def find_jar_iter(name_pattern, path_to_jar=None, env_vars=(),
#
# /Users/tomdunlap/anaconda3/envs/dl/lib/python3.6/site-packages/nltk/__init__.py in find_binary_iter(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     596     """
#     597     for file in  find_file_iter(path_to_bin or name, env_vars, searchpath, binary_names,
# --> 598                      url, verbose):
#     599         yield file
#     600
#
# /Users/tomdunlap/anaconda3/envs/dl/lib/python3.6/site-packages/nltk/__init__.py in find_file_iter(filename, env_vars, searchpath, file_names, url, verbose, finding_dir)
#     567                         (filename, url))
#     568         div = '='*75
# --> 569         raise LookupError('\n\n%s\n%s\n%s' % (div, msg, div))
#     570
#     571
#
# LookupError:
#
# ===========================================================================
# NLTK was unable to find the gs file!
# Use software specific configuration paramaters or set the PATH environment variable.
# ===========================================================================
# Tree('S', [Tree('NP', ['I']), Tree('VP', [Tree('VP', [Tree('V', ['shot']), Tree('NP', [Tree('Det', ['an']), Tree('N', ['elephant'])])]), Tree('PP', [Tree('P', ['in']), Tree('NP', [Tree('Det', ['my']), Tree('N', ['pajamas'])])])])])
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /Users/tomdunlap/anaconda3/envs/dl/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# /Users/tomdunlap/anaconda3/envs/dl/lib/python3.6/site-packages/nltk/tree.py in _repr_png_(self)
#     728             _canvas_frame.print_to_file(in_path)
#     729             _canvas_frame.destroy_widget(widget)
# --> 730             subprocess.call([find_binary('gs', binary_names=['gswin32c.exe', 'gswin64c.exe'], env_vars=['PATH'], verbose=False)] +
#     731                             '-q -dEPSCrop -sDEVICE=png16m -r90 -dTextAlphaBits=4 -dGraphicsAlphaBits=4 -dSAFER -dBATCH -dNOPAUSE -sOutputFile={0:} {1:}'
#     732                             .format(out_path, in_path).split())
#
# /Users/tomdunlap/anaconda3/envs/dl/lib/python3.6/site-packages/nltk/__init__.py in find_binary(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     602                 binary_names=None, url=None, verbose=False):
#     603     return next(find_binary_iter(name, path_to_bin, env_vars, searchpath,
# --> 604                                  binary_names, url, verbose))
#     605
#     606 def find_jar_iter(name_pattern, path_to_jar=None, env_vars=(),
#
# /Users/tomdunlap/anaconda3/envs/dl/lib/python3.6/site-packages/nltk/__init__.py in find_binary_iter(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     596     """
#     597     for file in  find_file_iter(path_to_bin or name, env_vars, searchpath, binary_names,
# --> 598                      url, verbose):
#     599         yield file
#     600
#
# /Users/tomdunlap/anaconda3/envs/dl/lib/python3.6/site-packages/nltk/__init__.py in find_file_iter(filename, env_vars, searchpath, file_names, url, verbose, finding_dir)
#     567                         (filename, url))
#     568         div = '='*75
# --> 569         raise LookupError('\n\n%s\n%s\n%s' % (div, msg, div))
#     570
#     571
#
# LookupError:
#
# ===========================================================================
# NLTK was unable to find the gs file!
# Use software specific configuration paramaters or set the PATH environment variable.
# ===========================================================================
# Tree('S', [Tree('NP', ['I']), Tree('VP', [Tree('V', ['shot']), Tree('NP', [Tree('Det', ['an']), Tree('N', ['elephant']), Tree('PP', [Tree('P', ['in']), Tree('NP', [Tree('Det', ['my']), Tree('N', ['pajamas'])])])])])])

# %%
from nltk import pos_tag, ne_chunk
from nltk.tokenize import word_tokenize

# Recognize named entities in a tagged sentence
tree = ne_chunk(pos_tag(word_tokenize("Antonio joined Udacity Inc. in California.")))
IPython.display.display(tree)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /Users/tomdunlap/anaconda3/envs/dl/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# /Users/tomdunlap/anaconda3/envs/dl/lib/python3.6/site-packages/nltk/tree.py in _repr_png_(self)
#     728             _canvas_frame.print_to_file(in_path)
#     729             _canvas_frame.destroy_widget(widget)
# --> 730             subprocess.call([find_binary('gs', binary_names=['gswin32c.exe', 'gswin64c.exe'], env_vars=['PATH'], verbose=False)] +
#     731                             '-q -dEPSCrop -sDEVICE=png16m -r90 -dTextAlphaBits=4 -dGraphicsAlphaBits=4 -dSAFER -dBATCH -dNOPAUSE -sOutputFile={0:} {1:}'
#     732                             .format(out_path, in_path).split())
#
# /Users/tomdunlap/anaconda3/envs/dl/lib/python3.6/site-packages/nltk/__init__.py in find_binary(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     602                 binary_names=None, url=None, verbose=False):
#     603     return next(find_binary_iter(name, path_to_bin, env_vars, searchpath,
# --> 604                                  binary_names, url, verbose))
#     605
#     606 def find_jar_iter(name_pattern, path_to_jar=None, env_vars=(),
#
# /Users/tomdunlap/anaconda3/envs/dl/lib/python3.6/site-packages/nltk/__init__.py in find_binary_iter(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     596     """
#     597     for file in  find_file_iter(path_to_bin or name, env_vars, searchpath, binary_names,
# --> 598                      url, verbose):
#     599         yield file
#     600
#
# /Users/tomdunlap/anaconda3/envs/dl/lib/python3.6/site-packages/nltk/__init__.py in find_file_iter(filename, env_vars, searchpath, file_names, url, verbose, finding_dir)
#     567                         (filename, url))
#     568         div = '='*75
# --> 569         raise LookupError('\n\n%s\n%s\n%s' % (div, msg, div))
#     570
#     571
#
# LookupError:
#
# ===========================================================================
# NLTK was unable to find the gs file!
# Use software specific configuration paramaters or set the PATH environment variable.
# ===========================================================================
# Tree('S', [Tree('PERSON', [('Antonio', 'NNP')]), ('joined', 'VBD'), Tree('ORGANIZATION', [('Udacity', 'NNP'), ('Inc.', 'NNP')]), ('in', 'IN'), Tree('GPE', [('California', 'NNP')]), ('.', '.')])

# %% [markdown]
# ## Stemming & Lemmatization
#
# ### Stemming

# %%
from nltk.stem.porter import PorterStemmer

# Reduce words to their stems
stemmed = [PorterStemmer().stem(w) for w in words]
print(stemmed)
# Out:
# ['first', 'time', 'see', 'second', 'renaiss', 'may', 'look', 'bore', 'look', 'least', 'twice', 'definit', 'watch', 'part', '2', 'chang', 'view', 'matrix', 'human', 'peopl', 'one', 'start', 'war', 'ai', 'bad', 'thing']

# %% [markdown]
# ### Lemmatization

# %%
from nltk.stem.wordnet import WordNetLemmatizer

# Reduce words to their root form
lemmed = [WordNetLemmatizer().lemmatize(w) for w in words]
print(lemmed)
# Out:
# ['first', 'time', 'see', 'second', 'renaissance', 'may', 'look', 'boring', 'look', 'least', 'twice', 'definitely', 'watch', 'part', '2', 'change', 'view', 'matrix', 'human', 'people', 'one', 'started', 'war', 'ai', 'bad', 'thing']

# %%
# Lemmatize verbs by specifying pos
lemmed = [WordNetLemmatizer().lemmatize(w, pos='v') for w in lemmed]
print(lemmed)
# Out:
# ['first', 'time', 'see', 'second', 'renaissance', 'may', 'look', 'bore', 'look', 'least', 'twice', 'definitely', 'watch', 'part', '2', 'change', 'view', 'matrix', 'human', 'people', 'one', 'start', 'war', 'ai', 'bad', 'thing']
